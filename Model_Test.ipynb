# %%
from model_types import DownsizeTransformer

model = DownsizeTransformer()
# Out:
# /home/araymond/storage/pyenv/versions/3.10.14/envs/mini/lib/python3.10/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# There was a problem when trying to write in your cache folder (/storage/cache). You should set the environment variable TRANSFORMERS_CACHE to a writable directory.

# %%
import torch 
data = torch.randn(10,1,64,64)
latents = torch.randn(10,5)

# %%
a, b = model(data, latents)

print(a.shape, b.shape)
# Out:
# torch.Size([10, 768]) torch.Size([10, 16])

# %%
y = latents
latents_diff = y.unsqueeze(1) - y.unsqueeze(0)

# %%
y
# Out:
# tensor([[-0.4593, -0.4535, -0.5533, -0.6955, -0.4059],
#         [-0.4051, -0.5855,  0.0291,  0.3412,  1.5174],
#         [-0.5523, -0.0081,  0.1002,  1.5596,  0.5979],
#         [ 0.5294,  0.3163, -0.6839, -0.3219,  1.8451],
#         [ 0.7101,  1.2852, -0.6832,  0.2147, -1.2625],
#         [ 0.3456,  1.2324,  1.8773, -1.0198, -0.0205],
#         [ 0.0981, -0.1202,  0.9638,  1.3627, -0.7280],
#         [ 0.5215,  0.1462,  0.9459, -1.1635,  0.8344],
#         [ 0.9970, -0.3144, -0.0656,  0.6362,  1.1180],
#         [-0.6733,  1.6552,  0.7756, -0.5186, -1.1047]])

# %%
latents_diff
# Out:
# tensor([[[ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [-5.4240e-02,  1.3200e-01, -5.8248e-01, -1.0367e+00, -1.9232e+00],
#          [ 9.2935e-02, -4.4540e-01, -6.5350e-01, -2.2551e+00, -1.0038e+00],
#          [-9.8872e-01, -7.6976e-01,  1.3053e-01, -3.7360e-01, -2.2510e+00],
#          [-1.1694e+00, -1.7386e+00,  1.2985e-01, -9.1020e-01,  8.5658e-01],
#          [-8.0493e-01, -1.6858e+00, -2.4307e+00,  3.2423e-01, -3.8539e-01],
#          [-5.5742e-01, -3.3325e-01, -1.5171e+00, -2.0583e+00,  3.2209e-01],
#          [-9.8082e-01, -5.9967e-01, -1.4993e+00,  4.6801e-01, -1.2403e+00],
#          [-1.4563e+00, -1.3908e-01, -4.8772e-01, -1.3318e+00, -1.5239e+00],
#          [ 2.1398e-01, -2.1087e+00, -1.3289e+00, -1.7690e-01,  6.9881e-01]],
#
#         [[ 5.4240e-02, -1.3200e-01,  5.8248e-01,  1.0367e+00,  1.9232e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
# ...
