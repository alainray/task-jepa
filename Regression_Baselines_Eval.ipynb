# %% [markdown]
# # Evaluación via Regresión Modelos de Extrapolación

# %%
from models import LightningRegression,LightningVersatile,create_model
from model_info import encoders, modulators, model_output_dims
from utils import set_seed, get_args, get_name_from_args
import torch
from datasets import IdSpritesEval
import pandas as pd
from tqdm.notebook import tqdm
from torch.utils.data import TensorDataset
from sklearn.model_selection import train_test_split


def get_dataloader(args, indices = []):
    
    data = torch.load(f"{args.dataset}/{args.dataset}.pth", map_location="cpu")
    reps_path = None
    if args.pretrained_reps:
        reps_path = args.pretrained_reps
    elif args.pretrained_encoder:
        encoder_args = get_args(args.pretrained_encoder)
        reps_path = encoder_args.pretrained_reps
    have_reps = reps_path is not None
    if have_reps:
        print("using pretrained reps...")
        data['reps'] = torch.load(f"{args.dataset}/{args.dataset}_images_feats_{reps_path}.pth", map_location="cpu") if reps_path else None
        data['reps'] = data['reps'] - data['reps'].mean(dim=0) # center
        data['reps'] = torch.nn.functional.normalize(data['reps'], p=2.0, dim=1, eps=1e-12)
    else:
        print("using input images")
    ds = TensorDataset(
                data['images'][indices],
                data['reps'][indices] if have_reps else data['latents'][indices],
                data['latent_ids'][indices]
                )
    dl = torch.utils.data.DataLoader(ds, batch_size=1024, shuffle=False)
    return dl
    
def evaluate(model, dataloader):
    def regression_metrics(logs, targets, mode="dim"):
        if mode == "dim":
            ss_res = torch.sum((targets - logs) ** 2, dim=0)
            mu = torch.mean(targets, dim=0)
            ss_tot = torch.sum((targets - mu)**2, dim=0)
            r2 = 1- ss_res/ss_tot
            mse = ss_res/targets.shape[0]
        else:
            ss_res = torch.sum((targets - logs) ** 2)
            mu = torch.mean(targets, dim=0)
            ss_tot = torch.sum((targets - mu)**2)
            r2 = 1- ss_res/ss_tot
            mse = ss_res/targets.shape[0]
        return r2, mse
    def accuracy(logs, targets):
        preds = torch.round(logs) 
        correct = (preds == targets).float().sum(dim=0)
        acc = correct/preds.shape[0]
        return acc

    model.eval()
    results = dict()
    logs = []
    targets = []
    same_logs = []
    same_tgts = []
    predict_method = model.split_step if args.train_method == "regression" else model.predict_regression
    with torch.no_grad():
        for n_batch, batch in enumerate(tqdm(dataloader)):
            # Unpack index + batch
            imgs, gt_reps, latents = batch
            data = predict_method((imgs.cuda(), gt_reps.cuda(), latents.cuda()))
            logs.append(data['logits'])
            targets.append(data['targets'])
            if "same_logits" in data:
                same_logs.append(data['same_logits'])
                same_tgts.append(data['same_tgts'])
        logs = torch.cat(logs, dim=0)    
        targets = torch.cat(targets, dim=0).float()
       
        results['r2_reg'], results['mse_reg'] = regression_metrics(logs,targets)
        results['acc_reg'] = accuracy(logs, targets)
        if len(same_logs) > 0:
            results['r2_same'], results['mse_same'] = regression_metrics(same_logs,same_targets)
        else:
            results['r2_same'] = results['mse_same'] = -10
        return results
# Out:
# /home/araymond/storage/pyenv/versions/3.10.14/envs/mini/lib/python3.10/site-packages/transformers/utils/hub.py:127: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# There was a problem when trying to write in your cache folder (/storage/cache). You should set the environment variable TRANSFORMERS_CACHE to a writable directory.

# %% [markdown]
# ## 1. Definir Experimentos a Procesar

# %%
# Define experiment ids for checkpoint
exps = [
        "ze2poky9", # rep_train(SAME)+ RDM 
        "b6l0zvfq", # rep_train(SAME)+ RDM 
        "xf2a1c3k", # rep_train(SAME)+ RDM 
        "0ziv0je0", # rep_train(SAME)+ RDM 
        "6hwr35jz", # rep_train(SAME)+ RDM 
        "adm2vtti", # rep_train(SAME)+ RDM 
        "aefm16na", # rep_train(SAME)+ RDM 
        "co93f2g7", # rep_train(SAME)+ RDM 
        "i221poen" # rep_train(SAME)+ RDM 
       ]

# %% [markdown]
# ## Creación Archivos CSV (Corren Regresión en Dataset)

# %%
for exp_id in tqdm(exps):
    args = get_args(exp_id)
    args.encoder['pretrain_method'] = None
    print(args)
    df = pd.DataFrame()
    for split in tqdm(['train','id','ood']):
        encoder, modulator, regressor = create_model(args)
        if args.train_method == "regression":
            model = LightningRegression.load_from_checkpoint(checkpoint_path=f"results/{args.dataset}/{exp_id}/last.ckpt", 
                                            args=args, 
                                            encoder=encoder, 
                                            modulator=modulator,
                                            regressor=regressor)
        else:
            model = LightningVersatile.load_from_checkpoint(checkpoint_path=f"results/{args.dataset}/{exp_id}/last.ckpt", 
                                            args=args, 
                                            encoder=encoder, 
                                            modulator=modulator,
                                            regressor=regressor)
        if split in ['train','id']:
            indices = torch.load(f"{args.dataset}/{args.dataset}_{args.sub_dataset}_train_indices.pth")
            train_indices, val_indices = train_test_split(indices, test_size = 0.1, random_state=42)
            indices = train_indices if split == "train" else val_indices
        elif split == "ood":
            indices = torch.load(f"{args.dataset}/{args.dataset}_{args.sub_dataset}_test_indices.pth")
        else:
            print("Split not recognized!")
            indices = []
        dl = get_dataloader(args, indices)
        results = evaluate(model, dl)
        r2 = results['r2_reg']
        mse = results['mse_reg']
        r2_same = results['r2_same']
        mse_same = results['mse_same']
        acc = results['acc_reg']
        # Store metadata
        meta = {
            'split': split,
            'dataset': args.dataset,
            'sub_dataset': args.sub_dataset,
            'model': get_name_from_args(args)
        }
        
        # Create a long-format DataFrame where each row is a (task, r2) pair
        rows = []
        for i, fov in enumerate(args.FOVS_PER_DATASET):
            rows.append({
                **meta,
                'task': fov,
                'r2': r2[i].item(),
                'mse': mse[i].item(),
                "acc": acc[i].item()*100
            })
        rows.append({**meta, 'task': "same", "r2": r2_same ,'mse': mse_same})
        # Append to df
        result_df = pd.DataFrame(rows)
        df = pd.concat([df, result_df], ignore_index=True)
    print(df)
    df.to_csv(f"results/{args.dataset}/{exp_id}_{args.dataset}_{args.sub_dataset}_{args.pretrained_reps}.csv")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 333, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'composition', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/253 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/29 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/732 [00:00<?, ?it/s]
#     split dataset  sub_dataset                           model  \
# 0   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 1   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 2   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 3   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 4   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 5   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 6   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 7   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 8      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 9      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 10     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 11     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 12     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 13     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 14     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 15     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  composition  rep_train_same_vit_l_32_random
#
#                 task         r2         mse         acc
# 0       object_color   0.999052    0.002765   99.980307
# 1       object_shape   0.989894    0.029481   97.684026
# 2        object_size   0.994425    0.001394   99.848616
# 3      camera_height   0.999029    0.000646  100.000000
# 4   background_color   0.998345    0.001103  100.000000
# 5             h_axis   0.999743    0.037284   97.709125
# 6             v_axis   0.999626    0.054342   95.476562
# 7               same -10.000000  -10.000000         NaN
# 8       object_color   0.998930    0.003122   99.965245
# 9       object_shape   0.977832    0.064563   96.479213
# 10       object_size   0.990358    0.002411   99.715000
# 11     camera_height   0.999014    0.000664   99.996525
# 12  background_color   0.998328    0.001117   99.996525
# 13            h_axis   0.999689    0.045285   96.527874
# 14            v_axis   0.999547    0.064828   93.702209
# 15              same -10.000000  -10.000000         NaN
# 16      object_color   0.989677    0.030108   98.658502
# 17      object_shape   0.311359    2.008536   65.557319
# 18       object_size   0.647996    0.088001   90.342790
# 19     camera_height   0.998887    0.000742   99.990124
# 20  background_color   0.994764    0.003491   99.981314
# 21            h_axis  -1.456849  236.471725    8.909367
# 22            v_axis  -0.694898  163.133911    6.365741
# 23              same -10.000000  -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 333, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'extrapolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.999021   0.001958   99.951416
# 1       object_shape   0.980605   0.056599   96.357381
# 2        object_size   0.995593   0.001102   99.876040
# 3      camera_height   0.999730   0.000067  100.000000
# 4   background_color   0.999717   0.000071  100.000000
# 5             h_axis   0.999503   0.053637   96.539921
# 6             v_axis   0.999392   0.065590   94.652349
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.998995   0.002006   99.948555
# 9       object_shape   0.967242   0.095088   95.145315
# 10       object_size   0.992888   0.001778   99.797451
# 11     camera_height   0.999727   0.000068   99.999994
# 12  background_color   0.999718   0.000071   99.999994
# 13            h_axis   0.999417   0.063304   95.190328
# 14            v_axis   0.999266   0.079294   92.431837
# 15              same -10.000000 -10.000000         NaN
# 16      object_color   0.064065   2.954244   59.867585
# 17      object_shape   0.139217   2.510617   60.756725
# 18       object_size   0.216911   0.195772   79.372245
# 19     camera_height   0.312462   0.475898   52.380949
# 20  background_color  -0.926177   1.333255   51.237458
# 21            h_axis   0.570545  60.835835   23.073329
# 22            v_axis   0.779722  31.204208   24.747437
# 23              same -10.000000 -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 333, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'interpolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.999309   0.002377   99.958920
# 1       object_shape   0.980489   0.056936   95.685083
# 2        object_size   0.992940   0.001765   99.804240
# 3      camera_height   0.999655   0.000345  100.000000
# 4   background_color   0.999897   0.000103  100.000000
# 5             h_axis   0.999337   0.089659   90.548551
# 6             v_axis   0.999247   0.101782   88.379127
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.999280   0.002476   99.945343
# 9       object_shape   0.959970   0.116197   93.827158
# 10       object_size   0.990579   0.002355   99.723506
# 11     camera_height   0.999655   0.000345   99.999994
# 12  background_color   0.999897   0.000103   99.999994
# 13            h_axis   0.999239   0.103627   88.769931
# 14            v_axis   0.999131   0.117637   86.287934
# 15              same -10.000000 -10.000000         NaN
# 16      object_color   0.537455   1.242515   69.576716
# 17      object_shape   0.303111   2.032593   59.106314
# 18       object_size   0.580632   0.104842   88.145804
# 19     camera_height   0.286352   0.373815   61.895251
# 20  background_color  -0.423118   0.745443   49.303076
# 21            h_axis   0.625129  49.630222   27.940917
# 22            v_axis   0.902589  12.896489   27.095321
# 23              same -10.000000 -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 222, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'composition', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/253 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/29 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/732 [00:00<?, ?it/s]
#     split dataset  sub_dataset                           model  \
# 0   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 1   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 2   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 3   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 4   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 5   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 6   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 7   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 8      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 9      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 10     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 11     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 12     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 13     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 14     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 15     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  composition  rep_train_same_vit_l_32_random
#
#                 task         r2         mse         acc
# 0       object_color   0.999288    0.002076   99.981469
# 1       object_shape   0.990184    0.028633   97.634590
# 2        object_size   0.996851    0.000787   99.932808
# 3      camera_height   0.999588    0.000274  100.000000
# 4   background_color   0.999781    0.000146  100.000000
# 5             h_axis   0.999735    0.038387   97.408283
# 6             v_axis   0.999627    0.054175   95.419794
# 7               same -10.000000  -10.000000         NaN
# 8       object_color   0.999169    0.002427   99.958295
# 9       object_shape   0.979272    0.060367   96.451408
# 10       object_size   0.994736    0.001316   99.854022
# 11     camera_height   0.999595    0.000273  100.000000
# 12  background_color   0.999781    0.000146  100.000000
# 13            h_axis   0.999680    0.046658   96.319336
# 14            v_axis   0.999538    0.066056   93.681359
# 15              same -10.000000  -10.000000         NaN
# 16      object_color   0.987137    0.037518   99.011064
# 17      object_shape   0.289767    2.071512   64.625120
# 18       object_size   0.592373    0.101907   89.328492
# 19     camera_height   0.995087    0.003275   99.997467
# 20  background_color   0.988305    0.007797   99.191153
# 21            h_axis  -1.327877  224.058151   10.180780
# 22            v_axis  -0.965244  189.154770    6.359467
# 23              same -10.000000  -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 222, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'extrapolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.998505   0.002990   99.972492
# 1       object_shape   0.985687   0.041769   96.734256
# 2        object_size   0.995230   0.001193   99.882472
# 3      camera_height   0.999193   0.000202  100.000000
# 4   background_color   0.999852   0.000037  100.000000
# 5             h_axis   0.999277   0.077939   92.830503
# 6             v_axis   0.999362   0.068835   94.128299
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.998457   0.003081   99.964631
# 9       object_shape   0.971637   0.082331   95.341432
# 10       object_size   0.994097   0.001476   99.829602
# 11     camera_height   0.999194   0.000201   99.999994
# 12  background_color   0.999848   0.000038   99.999994
# 13            h_axis   0.999192   0.087704   91.210133
# 14            v_axis   0.999227   0.083478   92.091048
# 15              same -10.000000 -10.000000         NaN
# 16      object_color  -0.117076   3.526008   55.091488
# 17      object_shape   0.267912   2.135257   57.056326
# 18       object_size   0.049311   0.237672   75.775874
# 19     camera_height   0.294282   0.488481   52.072585
# 20  background_color  -0.719689   1.190329   52.368277
# 21            h_axis   0.528210  66.832863   21.797839
# 22            v_axis   0.752367  35.079216   25.307953
# 23              same -10.000000 -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 222, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'interpolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.999209   0.002720   99.988210
# 1       object_shape   0.976437   0.068761   94.880974
# 2        object_size   0.992511   0.001872   99.783880
# 3      camera_height   0.999931   0.000069  100.000000
# 4   background_color   0.999851   0.000149  100.000000
# 5             h_axis   0.999391   0.082348   91.610938
# 6             v_axis   0.999376   0.084437   91.313726
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.999038   0.003310   99.967849
# 9       object_shape   0.957616   0.123030   93.360978
# 10       object_size   0.989252   0.002687   99.668849
# 11     camera_height   0.999930   0.000070   99.999994
# 12  background_color   0.999850   0.000150   99.999994
# 13            h_axis   0.999310   0.093937   89.898401
# 14            v_axis   0.999280   0.097474   89.403290
# 15              same -10.000000 -10.000000         NaN
# 16      object_color   0.410222   1.584296   70.744461
# 17      object_shape   0.191182   2.359052   55.444634
# 18       object_size   0.454149   0.136463   84.746748
# 19     camera_height   0.149977   0.445250   54.605931
# 20  background_color   0.158052   0.441020   54.900652
# 21            h_axis   0.773255  30.019398   25.304782
# 22            v_axis   0.779559  29.184750   25.131309
# 23              same -10.000000 -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 111, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'composition', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/253 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/29 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/732 [00:00<?, ?it/s]
#     split dataset  sub_dataset                           model  \
# 0   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 1   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 2   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 3   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 4   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 5   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 6   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 7   train   mpi3d  composition  rep_train_same_vit_l_32_random
# 8      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 9      id   mpi3d  composition  rep_train_same_vit_l_32_random
# 10     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 11     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 12     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 13     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 14     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 15     id   mpi3d  composition  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  composition  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  composition  rep_train_same_vit_l_32_random
#
#                 task         r2         mse         acc
# 0       object_color   0.999218    0.002280   99.973744
# 1       object_shape   0.985442    0.042468   97.377002
# 2        object_size   0.993105    0.001724   99.806136
# 3      camera_height   0.999921    0.000053  100.000000
# 4   background_color   0.999754    0.000164  100.000000
# 5             h_axis   0.999752    0.035941   98.026574
# 6             v_axis   0.999595    0.058924   94.960999
# 7               same -10.000000  -10.000000         NaN
# 8       object_color   0.999119    0.002571   99.940914
# 9       object_shape   0.971701    0.082419   95.919645
# 10       object_size   0.990132    0.002467   99.728900
# 11     camera_height   0.999920    0.000054  100.000000
# 12  background_color   0.999729    0.000181  100.000000
# 13            h_axis   0.999702    0.043458   96.972752
# 14            v_axis   0.999505    0.070757   93.316418
# 15              same -10.000000  -10.000000         NaN
# 16      object_color   0.987996    0.035013   98.423153
# 17      object_shape   0.363725    1.855802   63.937616
# 18       object_size   0.600903    0.099774   88.961512
# 19     camera_height   0.999252    0.000499  100.000000
# 20  background_color   0.997297    0.001802   99.940461
# 21            h_axis  -1.079359  200.138260    8.549997
# 22            v_axis  -1.011427  193.599838    6.337973
# 23              same -10.000000  -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 111, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'interpolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  interpolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.998799   0.004131   99.844247
# 1       object_shape   0.977549   0.065517   95.129603
# 2        object_size   0.989730   0.002567   99.725652
# 3      camera_height   0.999931   0.000069  100.000000
# 4   background_color   0.999897   0.000103  100.000000
# 5             h_axis   0.999250   0.101395   91.006160
# 6             v_axis   0.999423   0.078012   92.535794
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.998657   0.004617   99.813527
# 9       object_shape   0.963792   0.105101   93.717849
# 10       object_size   0.988183   0.002954   99.697787
# 11     camera_height   0.999932   0.000068   99.999994
# 12  background_color   0.999897   0.000103   99.999994
# 13            h_axis   0.999160   0.114321   89.541537
# 14            v_axis   0.999321   0.091999   90.496397
# 15              same -10.000000 -10.000000         NaN
# 16      object_color   0.594112   1.090319   68.533677
# 17      object_shape   0.193995   2.350847   58.635360
# 18       object_size   0.552542   0.111865   86.876929
# 19     camera_height   0.175417   0.431924   55.684799
# 20  background_color  -1.304193   1.206958   35.395861
# 21            h_axis   0.685242  41.671730   28.951994
# 22            v_axis   0.928992   9.400955   26.335153
# 23              same -10.000000 -10.000000         NaN
# {'lr': 0.001, 'wd': 0.04, 'arch': 'none', 'fovs': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'seed': 111, 'test': False, 'frozen': True, 'n_fovs': {'h_axis': 40, 'v_axis': 40, 'object_size': 2, 'object_color': 6, 'object_shape': 6, 'camera_height': 3, 'background_color': 3}, 'warmup': 6.666666666666667, 'dataset': 'mpi3d', 'encoder': {'arch': 'none', 'frozen': True, 'enc_dims': 16, 'pretrained': None, 'pretrain_method': None}, 'data_dir': '/mnt/nas2/GrimaRepo/araymond', 'enc_dims': 16, 'final_lr': 1e-06, 'final_wd': 0.4, 'fovs_ids': [0, 1, 2, 3, 4, 5, 6], 'mod_arch': 'mlp', 'mod_dims': 128, 'start_lr': 0.0002, 'train_bs': 256, 'ema_start': 0.996, 'ipe_scale': 1, 'modulator': {'arch': 'mlp', 'hidden_dim': 128}, 'num_steps': 200000, 'resume_id': None, 'fovs_tasks': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'num_epochs': 50, 'save_every': 10, 'fovs_levels': {'3dshapes': {'scale': 3, 'shape': 2, 'wall_hue': 2, 'floor_hue': 2, 'object_hue': 2, 'orientation': 3}, 'idsprites': {'x': 3, 'y': 3, 'scale': 3, 'shape': 3, 'orientation': 3}}, 'num_workers': 0, 'sub_dataset': 'extrapolation', 'fovs_indices': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}, 'save_metrics': True, 'save_weights': True, 'train_method': 'rep_train_same', 'experiment_id': None, 'iters_per_ema': 1, 'pretrain_method': None, 'pretrained_arch': None, 'pretrained_reps': 'vit_l_32', 'FOVS_PER_DATASET': ['object_color', 'object_shape', 'object_size', 'camera_height', 'background_color', 'h_axis', 'v_axis'], 'pretrained_feats': False, 'lambda_latent_loss': 1, 'pretrained_encoder': None, 'make_random_batches': True, 'task_to_label_index': {'h_axis': 5, 'v_axis': 6, 'object_size': 2, 'object_color': 0, 'object_shape': 1, 'camera_height': 3, 'background_color': 4}}
#   0%|          | 0/3 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/274 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/31 [00:00<?, ?it/s]
# using pretrained reps...
#   0%|          | 0/709 [00:00<?, ?it/s]
#     split dataset    sub_dataset                           model  \
# 0   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 1   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 2   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 3   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 4   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 5   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 6   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 7   train   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 8      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 9      id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 10     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 11     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 12     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 13     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 14     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 15     id   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 16    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 17    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 18    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 19    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 20    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 21    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 22    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
# 23    ood   mpi3d  extrapolation  rep_train_same_vit_l_32_random
#
#                 task         r2        mse         acc
# 0       object_color   0.998029   0.003944   99.831033
# 1       object_shape   0.980901   0.055734   96.095896
# 2        object_size   0.992121   0.001970   99.758875
# 3      camera_height   0.999411   0.000147  100.000000
# 4   background_color   0.999346   0.000164  100.000000
# 5             h_axis   0.999128   0.094014   89.945203
# 6             v_axis   0.999289   0.076739   92.800498
# 7               same -10.000000 -10.000000         NaN
# 8       object_color   0.998138   0.003716   99.852109
# 9       object_shape   0.966275   0.097895   94.659847
# 10       object_size   0.990857   0.002286   99.707431
# 11     camera_height   0.999409   0.000148   99.999994
# 12  background_color   0.999325   0.000169   99.999994
# 13            h_axis   0.999044   0.103859   88.567382
# 14            v_axis   0.999164   0.090282   90.483534
# 15              same -10.000000 -10.000000         NaN
# 16      object_color  -0.068587   3.372953   49.381751
# 17      object_shape   0.176968   2.400509   58.081871
# 18       object_size   0.169120   0.207720   78.331405
# 19     camera_height   0.331669   0.462603   52.380675
# 20  background_color  -0.507977   1.043787   50.298029
# 21            h_axis   0.588180  58.337654   25.451389
# 22            v_axis   0.786811  30.200024   26.503664
# 23              same -10.000000 -10.000000         NaN

# %% [markdown]
# ## Metadata

# %%
# 
exps = [
    "qp96yw83", # regression baseline
    "tgacyk73", # regression baseline
    "wfjnpd9k", # regression baseline
    "4pa7icuy", # regression baseline
    "3g8h1nfq", # regression baseline
    "aphsrlwg", # regression baseline
    "clcf7oin", # regression baseline
    "t4nfx11h", # regression baseline
    "t9w5qz8g",  # regression baseline
    'udnuj8i3', # rep_train(SAME, LINOP) + RDM
        '3if4e740',  # rep_train(SAME, LINOP) + RDM
        '8i0422lj',  # rep_train(SAME, LINOP) + RDM
        'ddc3hg7w',  # rep_train(SAME, LINOP) + RDM
        'e5b4alno',  # rep_train(SAME, LINOP) + RDM
        'g8kvz2d8', # rep_train(SAME, LINOP) + RDM
        'mcuz1c1m', # rep_train(SAME, LINOP) + RDM
        'woda8yw6', # rep_train(SAME, LINOP) + RDM
        'xka5ng1n', # rep_train(SAME, LINOP) + RDM
        "s9dcfkpf", # rep_train(SAME, LINOP) + RDM +UN
        "o0eqrqin", # rep_train(SAME, LINOP) + RDM +UN
        "o0uqa97p", # rep_train(SAME, LINOP) + RDM +UN
        "0wsipw6c", # rep_train(SAME, LINOP) + RDM +UN
        "onxxjg6c", # rep_train(SAME, LINOP) + RDM +UN
        "7e0qfq42", # rep_train(SAME, LINOP) + RDM +UN
        "0pyeiovd", # rep_train(SAME, LINOP) + RDM +UN
        "bjdyhddm", # rep_train(SAME, LINOP) + RDM +UN
        "btqvlusd", # rep_train(SAME, LINOP) + RDM +UN
        "ze2poky9", # rep_train(SAME)+ RDM 
        "b6l0zvfq", # rep_train(SAME)+ RDM 
        "xf2a1c3k", # rep_train(SAME)+ RDM 
        "0ziv0je0", # rep_train(SAME)+ RDM 
        "6hwr35jz", # rep_train(SAME)+ RDM 
        "adm2vtti", # rep_train(SAME)+ RDM 
        "aefm16na", # rep_train(SAME)+ RDM 
        "co93f2g7", # rep_train(SAME)+ RDM 
        "i221poen", # rep_train(SAME)+ RDM 
        "5dfeqofg", # MOD REGRESSION + RDM
        "l78rkpl6", # MOD REGRESSION + RDM
        "5e6ut80u", # MOD REGRESSION + RDM
        "nvw4hweu", # MOD REGRESSION + RDM
        "2bntzmyt", # MOD REGRESSION + RDM
        "5glq8j5y", # MOD REGRESSION + RDM
        "sw308xe5", # MOD REGRESSION + RDM
        "u9otp2tk", # MOD REGRESSION + RDM
        "sfiiqnyw" # MOD REGRESSION + RDM
       ]

exps = [ # 3dshapes
    "ntlfv56t", # rep_train same + REG + RDM + FILM + UN_MOD
    "ai37d6yl", # rep_train same + REG + RDM + FILM + UN_MOD
    "cvmqh7zk", # rep_train same + REG + RDM + FILM + UN_MOD
    "gqif1rpl", # rep_train same + REG + RDM + FILM + UN_MOD
    "4qb6mbue", # rep_train same + REG + RDM + FILM + UN_MOD
    "8c5rpv6v", # rep_train same + REG + RDM + FILM + UN_MOD
    "91lbgcry", # rep_train same + REG + RDM + FILM + UN_MOD
    "jznsk0ar", # rep_train same + REG + RDM + FILM + UN_MOD
    "pz175tk9", # rep_train same + REG + RDM + FILM + UN_MOD
    "m3jzscq5", # rep_train same + REG + RDM + LINOP + UN_MOD
    "e99wn9i9", # rep_train same + REG + RDM + LINOP + UN_MOD
    "i1h2ptub", # rep_train same + REG + RDM + LINOP + UN_MOD
    "hs3twhwv", # rep_train same + REG + RDM + LINOP + UN_MOD
    "bzv1fds7", # rep_train same + REG + RDM + LINOP + UN_MOD
    "2xuk4rml", # rep_train same + REG + RDM + LINOP + UN_MOD
    "tgjidf5z", # rep_train same + REG + RDM + LINOP + UN_MOD
    "i35hbd07", # rep_train same + REG + RDM + LINOP + UN_MOD
    "20vqzi7o", # rep_train same + REG + RDM + LINOP + UN_MOD
    "96yex98j", # MODREG + RDM + LINOP + UN_MOD
    "ufplly0f", # MODREG + RDM + LINOP + UN_MOD
    "tv4m97cy", # MODREG + RDM + LINOP + UN_MOD
    "sl7cdgtr", # MODREG + RDM + LINOP + UN_MOD
    "rqibwv3l", # MODREG + RDM + LINOP + UN_MOD
    "nc422yyl", # MODREG + RDM + LINOP + UN_MOD
    "bm1mg0hh", # MODREG + RDM + LINOP + UN_MOD
    "62t4uxfa", # MODREG + RDM + LINOP + UN_MOD
    "zhjiji9k", # MODREG + RDM + LINOP + UN_MOD
    "fqd7lb6c", # rep_train same + REG + RDM + LINOP
    "07rd68b4", # rep_train same + REG + RDM + LINOP
    "0fusfr05", # rep_train same + REG + RDM + LINOP
    "46swehpw", # rep_train same + REG + RDM + LINOP
    "p9ox7fcm", # rep_train same + REG + RDM + LINOP
    "u51k0c6s", # rep_train same + REG + RDM + LINOP
    "vjtx7e81", # rep_train same + REG + RDM + LINOP
    "4qzis3s0", # rep_train same + REG + RDM + LINOP
    "ujlxzsb9", # rep_train same + REG + RDM + LINOP
    "n49kztk8", # mod regression + RDM + LATDIR
    "6g833bpr", # mod regression + RDM + LATDIR
    "42wx79f8", # mod regression + RDM + LATDIR
    "awdihwps", # mod regression + RDM + LATDIR
    "m4sf4hkk", # mod regression + RDM + LATDIR
    "6ja2ednk", # mod regression + RDM + LATDIR
    "omi3q31m", # mod regression + RDM + LATDIR
    "3f7highk", # mod regression + RDM + LATDIR
    "5e2h1l0e", # mod regression + RDM + LATDIR
    "nbtscppe", # rep_train same + REG + RDM + LATDIR
    "g1wkqai8", # rep_train same + REG + RDM + LATDIR
    "gp51jqdv", # rep_train same + REG + RDM + LATDIR
    "f73kjyvt", # rep_train same + REG + RDM + LATDIR
    "hc2fqhgt", # rep_train same + REG + RDM + LATDIR
    "j2kp78sn", # rep_train same + REG + RDM + LATDIR
    "nbtscppe", # rep_train same + REG + RDM + LATDIR
    "onvvto74", # rep_train same + REG + RDM + LATDIR
    "xj5bewsj", # rep_train same + REG + RDM + LATDIR
    
    "ceeun18x", # mod regression + RDM + LINOP
    "0tb8d0of", # mod regression + RDM + LINOP
    "0cf0y4op", # mod regression + RDM + LINOP
    "v9ku7xke", # mod regression + RDM + LINOP
    "g9fvdqs6", # mod regression + RDM + LINOP
    "i0gfw7sg", # mod regression + RDM + LINOP
    "o5vtujdk", # mod regression + RDM + LINOP
    "rx6nzxkx", # mod regression + RDM + LINOP
    "soub0i38", # mod regression + RDM + LINOP
    "i6msf1v8", # cnn modregression + random
    "rvei4qfz", # cnn modregression + random
    "s21bpu3a", # cnn modregression + random
    "1s89r7jg", # cnn modregression + random
    "uf7so6b2", # cnn modregression + random
    "onj3hzza", # cnn modregression + random
    "z0ijmy7x", # baseline regression scratch
    "yj9ixz8m", # baseline regression scratch
    "wet3xlav", # baseline regression scratch
    "rj8kmlgh", # baseline regression scratch
    "d5y0fcks", # baseline regression scratch
    "1ft0hp2e", # baseline regression scratch
    "dbe02hpj", # baseline regression scratch
    "cb0tgzzn", # baseline regression scratch
    "y1q6brv7", # baseline regression scratch
    "ec23sm1i", # CNN + rep_train(same) + reg + random
    "a7ws7cmq", # CNN + rep_train(same) + reg + random
    "zil44kpc", # CRASHED
    "5tv259yn", # CNN + rep_train(same) + reg + random
    "yr1dv4v6", # CNN + rep_train(same) + reg + random
    "zhqvr0lz", # CNN + rep_train(same) + reg + random 
    "t3gy9jk0", # CNN + rep_train(same) + reg + random
    "etui8as9", # CNN + rep_train(same) + reg + random
    "khxm7swv", # CNN + rep_train(same) + reg + random
    "c01smllr", # rep_train (residual) + same loss + regresion
    "2gk0zv3g",  # rep_train (residual) + same loss + regresion 
    "gzf0su5r",  # rep_train (residual) + same loss + regresion
    "ee2s99re",  # rep_train (residual) + same loss + regresion 
    "9gsdaqxd",  # rep_train (residual) + same loss + regresion 
    "cgrsl3av",  # rep_train (residual) + same loss + regresion 
    "crlqukzd",  # rep_train (residual) + same loss + regresion + random
    "qs7tezcp",  # rep_train (residual) + same loss + regresion + random
    "teh0lkys",  # rep_train (residual) + same loss + regresion + random
    "hz324tl1",  # rep_train (residual) + same loss + regresion + random
    "ijgamtnm",  # rep_train (residual) + same loss + regresion + random
    "wsd9ajz4", # rep_train (residual) + same loss + regresion + random
    "c3i8m2li", # rep_train + regression + random
    "le9tapxr",  # rep_train + regression + random
    "m3s9rawj",  # rep_train + regression + random
    "oykmci7n",  # rep_train + regression + random
    "13hgsljh", # rep train same + random
    "6kgq972p",  # rep train same + random
    "qr3o8g18", # rep_train same + random
    "ggr210j7", # rep_train same + random
    "btlbgiyw", # rep_train same + random
    "4qwcrwdo", # rep_train same + random
    "jhlkudqc", # mod regression + random
    "dy0g90yf", # mod regression + random
    "l7287kha", # mod regression + random
    "pdvuzeik", # mod regression + random
    "5nneg1v2", # mod regression + random
    "slhukb7t", # mod regression + random
    "6vkh3xiw", # rep_train same 
    "75t0lezc",  # rep_train same 
    "aj0sty26",  # rep_train same 
    "vwmjtne3",  # rep_train same 
    "i7crcxpp",  # rep_train same 
    "nrc8fsoq",  # rep_train same 
    "gee639pm", # baseline regression
    "kcpnt121", # baseline regression
    "z1fo3hf6", # baseline regression
    "bq4qhtxu", # baseline regression
    "f7yr1a78", # baseline regression
    "v8f31pyn", # baseline regression
    
    "c3i8m2li", # rep_train_plus extrapolation + random
    "le9tapxr", # rep_train_plus extrapolation + random
    "m3s9rawj", # rep_train_plus correct interpolation + ramdom
    "oykmci7n", # rep_train_plus correct interpolation + random
    "7l4txq1v", # rep_train_plus extrapolation
    "xg98v4xi", # rep_train_plus extrapolation
    "2r381uwd", # rep_train_plus extrapolation
    "tfa3zh2n", # rep_train_plus correct
    
    "sfl4cr53", # mod_regression extrapolation
    "91ktdndl", # mod regression
    "b36si90c", # mod regression
    "08vym6tg", # mod regression
    "irlsradb",# mod regression
    "esef85yi", # non_mod_regression composition
    "kpui77ip", # non_mod_regression composition
    "ihw7cd8h", # mod_regression composition
     "bqn7ytvr", # non mod regression interpolation
    "50jpen48", # mod regression interpolation
    "w9epqele", # non mod regression interpolation
    "np596yq5", # mod regression interpolation
     "co7i15y6", # rep_train (film) + SAME + REG + random
    "aa4xwwhq", # rep_train (film) + SAME + REG + random
    "oczdrid9", # rep_train (film) + SAME + REG + random
    "wbjo218x", # rep_train (film) + SAME + REG + random
    "2jua32og", # rep_train (film) + SAME + REG + random
    "53e9n83t", # rep_train (film) + SAME + REG + random
    "aeqigwxc", # rep_train (film) + SAME + REG + random
    "kskpufht", # rep_train (film) + SAME + REG + random
    "un7b247p", # rep_train (film) + SAME + REG + random
    "e0cn4e4f", # rep_train (transformer) + SAME + REG + random
    "fyncud9n", # rep_train (transformer) + SAME + REG + random
    "r32wp7e3", # rep_train (transformer) + SAME + REG + random
    "nmy0v96r", # rep_train (transformer) + SAME + REG + random
    "fqzsr1vf", # rep_train (transformer) + SAME + REG + random
    "mot5a4ku", # rep_train (transformer) + SAME + REG + random
    "q7fkbt0g", # rep_train (transformer) + SAME + REG + random
    "qj42vq3i", # rep_train (transformer) + SAME + REG + random
    "sxigun9n", # rep_train (transformer) + SAME + REG + random
    "7k8mxkwj", # mod_regression (transformer) + random
    "d2assvyp", # mod_regression (transformer) + random
    "bmb752uz", # mod_regression (transformer) + random
    "dax881de", # mod_regression (transformer) + random
    "87cd47fx", # mod_regression (transformer) + random
    "a2waa2j0", # mod_regression (transformer) + random
    "nsbutuwv", # mod_regression (transformer) + random
    "ntxtml07", # mod_regression (transformer) + random
    "zyzjokml", # mod_regression (transformer) + random
    "7k8mxkwj", # mod_regression (film) + random,
    "d2assvyp", # mod_regression (film) + random,
    "bmb752uz", # mod_regression (film) + random,
    "dax881de", # mod_regression (film) + random,
    "87cd47fx", # mod_regression (film) + random,
    "a2waa2j0", # mod_regression (film) + random,
    "nsbutuwv", # mod_regression (film) + random,
    "ntxtml07", # mod_regression (film) + random,
    "zyzjokml", # mod_regression (film) + random,
    "co7i15y6", # rep_train (film) + SAME + REG + random
    "aa4xwwhq", # rep_train (film) + SAME + REG + random
    "oczdrid9", # rep_train (film) + SAME + REG + random
    "wbjo218x", # rep_train (film) + SAME + REG + random
    "2jua32og", # rep_train (film) + SAME + REG + random
    "53e9n83t", # rep_train (film) + SAME + REG + random
    "aeqigwxc", # rep_train (film) + SAME + REG + random
    "kskpufht", # rep_train (film) + SAME + REG + random
    "un7b247p", # rep_train (film) + SAME + REG + random
    "e0cn4e4f", # rep_train (transformer) + SAME + REG + random
    "fyncud9n", # rep_train (transformer) + SAME + REG + random
    "r32wp7e3", # rep_train (transformer) + SAME + REG + random
    "nmy0v96r", # rep_train (transformer) + SAME + REG + random
    "fqzsr1vf", # rep_train (transformer) + SAME + REG + random
    "mot5a4ku", # rep_train (transformer) + SAME + REG + random
    "q7fkbt0g", # rep_train (transformer) + SAME + REG + random
    "qj42vq3i", # rep_train (transformer) + SAME + REG + random
    "sxigun9n", # rep_train (transformer) + SAME + REG + random
    "7k8mxkwj", # mod_regression (transformer) + random
    "d2assvyp", # mod_regression (transformer) + random
    "bmb752uz", # mod_regression (transformer) + random
    "dax881de", # mod_regression (transformer) + random
    "87cd47fx", # mod_regression (transformer) + random
    "a2waa2j0", # mod_regression (transformer) + random
    "nsbutuwv", # mod_regression (transformer) + random
    "ntxtml07", # mod_regression (transformer) + random
    "zyzjokml" # mod_regression (transformer) + random '''
#     ]
]

names = {  
           'mod_regression_latdir_vit_l_32_random': "MODREG(LATDIR)+RDM",
           'rep_train_same_linop_vit_l_32_random': "LSM(SAME,LINOP)+REG+RDM",
           'rep_train_same_linop_vit_l_32_random_un': "LSM(SAME,LINOP)+REG+RDM+UN",
           'rep_train_same_latdir_vit_l_32_random': "LSM(SAME,LATDIR)+REG+RDM",
           'mod_regression_linop_vit_l_32_random':  "MODREG(LINOP)+RDM",
           'mod_regression_linop_vit_l_32_random_un':  "MODREG(LINOP)+RDM+UN",
           'mod_regression_vit_l_32': "MODREG",
           "mod_regression_mod_regressioncnn_random":"CNN-MODREG+RDM",
           'mod_regression_vit_l_32_random': "MODREG+RDM" ,
           'non_mod_regression_vit_l_32': "NON-MODREG+RDM", 
           'regressioncnn': "CNN-REG (BASELINE)",
           'rep_train_plus_vit_l_32': "LSM(CLASS)+REG",
           'rep_train_plus_vit_b_32': "LSM(CLASS)+REG (b32)",
           'rep_train_plus_vit_l_32_random': "LSM(CLASS)+REG+RDM",
           'rep_train_same_res_vit_l_32': "LSM(SAME,RES)+REG",  
           'rep_train_same_res_vit_l_32_random': "LSM(SAME,RES)+REG+RDM",
           'rep_train_same_vit_l_32':"LSM(SAME)+REG",  
           'rep_train_same_vit_l_32_random': "LSM(SAME)+REG+RDM",
           'rep_train_same_rep_train_samecnn_random': "CNN-LSM(SAME)+REG+RDM",
           'vit_l_32': "REG (BASELINE)",
           'mod_regression_vit_b_32': "MODREG",
           'non_mod_regression_vit_b_32': "NON-MODREG",
           "rep_train_same_trans_vit_l_32_random": "LSM(SAME,TRANS)+REG+RDM",
           "rep_train_same_film_vit_l_32_random": "LSM(SAME,FILM)+REG+RDM",
           "rep_train_same_film_vit_l_32_random_un": "LSM(SAME,FILM)+REG+RDM+UN",
           "mod_regression_trans_vit_l_32_random": "MODREG(TRANS)+RDM",
           "mod_regression_film_vit_l_32_random": "MODREG(FILM)+RDM",
           "mod_regression_film_vit_l_32_random_un": "MODREG(FILM)+RDM+UN"
        }
custom_order = ['CNN-REG (BASELINE)', 
                'REG (BASELINE)',
               # 'NON-MODREG',
                #'NON-MODREG+RDM',
                'MODREG',
                "CNN-MODREG+RDM",
                'MODREG+RDM',
                "MODREG(TRANS)+RDM",
                "MODREG(FILM)+RDM",
                "MODREG(FILM)+RDM+UN",
                "MODREG(LATDIR)+RDM",
                "MODREG(LINOP)+RDM",
                "MODREG(LINOP)+RDM+UN",
                'LSM(CLASS)+REG',
                #"LSM(CLASS)+REG (b32)",
                "CNN-LSM(SAME)+REG+RDM",
                'LSM(CLASS)+REG+RDM',
                'LSM(SAME)+REG',
                'LSM(SAME)+REG+RDM',
                'LSM(SAME,RES)+REG', 
                'LSM(SAME,RES)+REG+RDM',
                "LSM(SAME,TRANS)+REG+RDM",
                "LSM(SAME,FILM)+REG+RDM",
                "LSM(SAME,FILM)+REG+RDM+UN",
                "LSM(SAME,LINOP)+REG+RDM",
                "LSM(SAME,LINOP)+REG+RDM+UN",
                "LSM(SAME,LATDIR)+REG+RDM"
     ]
exclude_models = {"NON-MODREG", "LSM(CLASS)+REG (b32)","NON-MODREG+RDM"}

# %% [markdown]
# ## Procesamiento Archivos CSV

# %%
import pandas as pd
from tqdm.notebook import tqdm

dataset = "mpi3d"
final_result = pd.DataFrame()
for exp_id in tqdm(exps):
    args = get_args(exp_id)
    filename = f"results/{args.dataset}/{exp_id}_{args.dataset}_{args.sub_dataset}_{args.pretrained_reps}.csv"
    exp_id, dataset, sub_dataset = filename.split("_")[:3]
    pretrained_reps = "-".join(filename.split("_")[3:]).replace(".csv","")
    df= pd.read_csv(filename)
    df.rename(columns={'correct': 'accuracy'}, inplace=True)
    df = df.pivot_table(
        index=["split","dataset",'sub_dataset', 'model'],
        columns='task',
        values=['acc',"r2","mse"]
    ).reset_index()
    final_result = pd.concat([final_result, df])


# Save as file
factors = {
        '3dshapes': ['floor_hue', 'object_hue', 'orientation', 'scale', 'shape', 'wall_hue'],
          'mpi3d': ['background_color', 'camera_height','h_axis', 'object_color', 'object_shape', 'object_size','v_axis'],
        'dsprites':  ["shape","scale","orientation","x","y"]
          }


print(final_result)
# Get average column value for high level evaluation
final_result['acc_mean'] = final_result['acc'][factors[dataset]].mean(axis=1)
final_result['r2_mean']  = final_result['r2'][factors[dataset]].mean(axis=1)
final_result['mse_mean'] = final_result['mse'][factors[dataset]].mean(axis=1)
final_result.to_csv(f"results/{dataset}/results_{dataset}.csv")
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]
#       split dataset    sub_dataset                           model  \
# task
# 0        id   mpi3d    composition                        vit_l_32
# 1       ood   mpi3d    composition                        vit_l_32
# 2     train   mpi3d    composition                        vit_l_32
# 0        id   mpi3d    composition                        vit_l_32
# 1       ood   mpi3d    composition                        vit_l_32
# ..      ...     ...            ...                             ...
# 1       ood   mpi3d    composition  mod_regression_vit_l_32_random
# 2     train   mpi3d    composition  mod_regression_vit_l_32_random
# 0        id   mpi3d  interpolation  mod_regression_vit_l_32_random
# 1       ood   mpi3d  interpolation  mod_regression_vit_l_32_random
# 2     train   mpi3d  interpolation  mod_regression_vit_l_32_random
#
#                   acc                                                     \
# task background_color camera_height     h_axis object_color object_shape
# 0           99.993050     99.993050  97.448909    99.944389    95.777142
# 1           99.812710     99.867839  11.524414    98.988503    64.898920
# 2           99.999231     99.999619  98.357928    99.969494    97.039860
# 0          100.000000    100.000000  97.424579    99.979144    95.822328
# 1           99.997866     99.999738  12.246625    99.225062    64.697206
# ..                ...           ...        ...          ...          ...
# 1           99.999601     99.999201  10.076787    97.571850    64.681721
# 2          100.000000    100.000000  97.728050    99.918520    97.962469
# 0           99.983925     99.999994  94.393003    99.958199    95.254624
# 1           28.525406     53.137124  32.064456    63.905561    65.228313
# 2           99.995714    100.000000  95.747244    99.968207    96.663880
#
#                   ...   mse                           r2                \
# task object_size  ...  same      v_axis background_color camera_height
# 0      99.440426  ... -10.0    0.057050         0.999732      0.999815
# 1      88.631380  ... -10.0  156.632538         0.996703      0.997670
# 2      99.583691  ... -10.0    0.045897         0.999760      0.999866
# 0      99.704576  ... -10.0    0.058036         0.998881      0.999155
# 1      88.510966  ... -10.0  144.658615         0.997301      0.996337
# ..           ...  ...   ...         ...              ...           ...
# 1      85.275966  ... -10.0  181.494003         0.999250      0.998894
# 2      99.926239  ... -10.0    0.056014         0.999879      0.999969
# 0      99.495238  ... -10.0    0.087210         0.999321      0.999807
# 1      61.633873  ... -10.0   16.035337        -1.836653      0.109767
# 2      99.648136  ... -10.0    0.073764         0.999524      0.999810
#
#
# task    h_axis object_color object_shape object_size  same    v_axis
# 0     0.999685     0.999045     0.967987    0.981143 -10.0  0.999601
# 1    -1.166770     0.993037     0.339236    0.583318 -10.0 -0.627351
# 2     0.999733     0.999162     0.981379    0.985576 -10.0  0.999684
# 0     0.999682     0.999697     0.970537    0.989682 -10.0  0.999594
# 1    -1.183222     0.994114     0.397314    0.569594 -10.0 -0.502947
# ..         ...          ...          ...         ...   ...       ...
# 1    -1.066540     0.989115     0.247690    0.446544 -10.0 -0.885652
# 2     0.999746     0.999477     0.989800    0.996571 -10.0  0.999615
# 0     0.999504     0.999198     0.969667    0.981039 -10.0  0.999356
# 1     0.766459     0.470304     0.285867   -0.407515 -10.0  0.878881
# 2     0.999566     0.999254     0.985256    0.985023 -10.0  0.999455
#
# [135 rows x 27 columns]

# %%
final_result.columns
# Out:
# MultiIndex([(      'split',                 ''),
#             (    'dataset',                 ''),
#             ('sub_dataset',                 ''),
#             (      'model',                 ''),
#             (        'acc', 'background_color'),
#             (        'acc',    'camera_height'),
#             (        'acc',           'h_axis'),
#             (        'acc',     'object_color'),
#             (        'acc',     'object_shape'),
#             (        'acc',      'object_size'),
#             (        'acc',           'v_axis'),
#             (        'mse', 'background_color'),
#             (        'mse',    'camera_height'),
#             (        'mse',           'h_axis'),
#             (        'mse',     'object_color'),
#             (        'mse',     'object_shape'),
#             (        'mse',      'object_size'),
#             (        'mse',             'same'),
#             (        'mse',           'v_axis'),
#             (         'r2', 'background_color'),
#             (         'r2',    'camera_height'),
#             (         'r2',           'h_axis'),
#             (         'r2',     'object_color'),
#             (         'r2',     'object_shape'),
#             (         'r2',      'object_size'),
#             (         'r2',             'same'),
#             (         'r2',           'v_axis'),
#             (   'acc_mean',                 ''),
#             (    'r2_mean',                 ''),
#             (   'mse_mean',                 '')],
#            names=[None, 'task'])

# %% [markdown]
# ## Resultados Generales

# %%
import pandas as pd
dataset = "3dshapes"
df = pd.read_csv(f"results/{dataset}/results_{dataset}.csv")
df = df.drop(0)
df = df[['split','dataset','sub_dataset','model','acc_mean','r2_mean','mse_mean']]
# Ordenar y limpiar nombres de modelo
df['model'] = df['model'].apply(lambda x: names[x])
df['model'] = pd.Categorical(df['model'], categories=custom_order, ordered=True)
df = df[~df["model"].isin(exclude_models)]
df = df.sort_values('model')
grouped = df.groupby(['split', 'dataset','sub_dataset', 'model']).agg(['mean', 'std'])
task_cols =['r2_mean','acc_mean','mse_mean']
# Flatten MultiIndex columns: ('floor_hue', 'mean') → 'floor_hue_mean'
grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]
grouped = grouped.reset_index()

# Format each task column as "mean ± std"
for col in task_cols:
    
    mean_col = f'{col}_mean'
    std_col = f'{col}_std'
    grouped[col] = grouped.apply(
        lambda row: f"{row[mean_col]:.3f} ± {row[std_col]:.3f}", axis=1
    )

# Drop the now-redundant mean and std columns
grouped = grouped.drop(columns=[f'{col}_mean' for col in task_cols] + [f'{col}_std' for col in task_cols])

df = grouped.pivot_table(
    index=["split","dataset", 'model'],
    columns='sub_dataset',
    values=['acc_mean',"r2_mean","mse_mean"],
    aggfunc="first"   # ← Just take the first, don't try to average
)
# 2. Swap levels so that sub_dataset comes first, then metric
df.columns = df.columns.swaplevel(0, 1)

# 3. Sort columns so sub_dataset1 → [acc, r2, mse], then sub_dataset2 → ...
df = df.sort_index(axis=1, level=0)

# 4. Reset index as usual
df = df.reset_index()
# Out:
# /tmp/ipykernel_281237/1971198888.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['split', 'dataset','sub_dataset', 'model']).agg(['mean', 'std'])
# /tmp/ipykernel_281237/1971198888.py:29: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df = grouped.pivot_table(

# %%
import numpy as np
df[df['split']=='ood'].replace(r"nan ± nan", np.nan, regex=True).dropna(how="any")
# Out:
# sub_dataset split   dataset                       model      composition  \
#                                                                 acc_mean
# 24            ood  3dshapes          CNN-REG (BASELINE)   99.999 ± 0.002
# 26            ood  3dshapes                      MODREG   82.600 ± 2.748
# 29            ood  3dshapes           MODREG(TRANS)+RDM  50.831 ± 25.023
# 32            ood  3dshapes          MODREG(LATDIR)+RDM   89.856 ± 1.519
# 33            ood  3dshapes           MODREG(LINOP)+RDM   90.416 ± 3.243
# 34            ood  3dshapes        MODREG(LINOP)+RDM+UN   88.126 ± 6.735
# 35            ood  3dshapes              LSM(CLASS)+REG     53.175 ± nan
# 36            ood  3dshapes       CNN-LSM(SAME)+REG+RDM  86.080 ± 15.128
# 42            ood  3dshapes     LSM(SAME,TRANS)+REG+RDM   63.722 ± 6.259
# 43            ood  3dshapes      LSM(SAME,FILM)+REG+RDM   93.855 ± 0.421
# 44            ood  3dshapes   LSM(SAME,FILM)+REG+RDM+UN   93.909 ± 0.705
# 45            ood  3dshapes     LSM(SAME,LINOP)+REG+RDM   85.430 ± 1.821
# 46            ood  3dshapes  LSM(SAME,LINOP)+REG+RDM+UN   89.165 ± 3.291
# 47            ood  3dshapes    LSM(SAME,LATDIR)+REG+RDM   89.704 ± 7.555
#
# sub_dataset                                 extrapolation                  \
#                   mse_mean        r2_mean        acc_mean        mse_mean
# 24           0.001 ± 0.000  1.000 ± 0.000  71.979 ± 0.881  10.679 ± 0.239
# 26           0.480 ± 0.046  0.939 ± 0.002  67.183 ± 0.590   5.738 ± 0.740
# 29           3.244 ± 3.029  0.543 ± 0.452  66.143 ± 1.551   4.873 ± 0.195
# 32           0.306 ± 0.204  0.967 ± 0.017  70.436 ± 0.802   5.057 ± 0.097
# 33           0.142 ± 0.028  0.983 ± 0.002  69.947 ± 0.477   4.012 ± 0.149
# 34           0.351 ± 0.344  0.968 ± 0.022  70.351 ± 0.054   4.315 ± 0.282
# 35             0.735 ± nan    0.892 ± nan    61.492 ± nan     5.212 ± nan
# 36           0.186 ± 0.236  0.974 ± 0.033  70.865 ± 0.536   8.864 ± 1.355
# 42           1.313 ± 0.429  0.835 ± 0.048  67.635 ± 0.595   5.214 ± 1.027
# 43           0.183 ± 0.018  0.980 ± 0.002  70.049 ± 0.224   4.945 ± 0.498
# 44           0.138 ± 0.020  0.982 ± 0.002  70.131 ± 0.037   4.720 ± 0.371
# 45           0.237 ± 0.030  0.972 ± 0.005  68.070 ± 0.733   3.968 ± 0.083
# 46           0.172 ± 0.034  0.978 ± 0.004  67.702 ± 0.464   3.855 ± 0.204
# 47           0.213 ± 0.109  0.973 ± 0.013  70.788 ± 0.114   4.894 ± 0.124
#
# sub_dataset                   interpolation
#                     r2_mean        acc_mean       mse_mean        r2_mean
# 24           -0.183 ± 0.019  79.170 ± 0.092  0.191 ± 0.007  0.974 ± 0.001
# 26            0.530 ± 0.036  79.479 ± 3.890  0.343 ± 0.098  0.962 ± 0.010
# 29            0.591 ± 0.022  73.629 ± 0.376  0.381 ± 0.038  0.954 ± 0.004
# 32            0.575 ± 0.011  77.905 ± 1.190  0.293 ± 0.024  0.964 ± 0.004
# 33            0.634 ± 0.018  85.694 ± 0.232  0.204 ± 0.017  0.976 ± 0.002
# 34            0.629 ± 0.029  79.779 ± 0.466  0.250 ± 0.006  0.969 ± 0.001
# 35              0.544 ± nan    79.319 ± nan    0.275 ± nan    0.964 ± nan
# 36            0.036 ± 0.157  79.084 ± 1.965  0.185 ± 0.020  0.974 ± 0.002
# 42            0.570 ± 0.055  72.280 ± 2.319  0.448 ± 0.015  0.949 ± 0.001
# 43            0.587 ± 0.022  81.081 ± 1.015  0.234 ± 0.014  0.972 ± 0.002
# 44            0.604 ± 0.031  78.442 ± 0.664  0.287 ± 0.045  0.965 ± 0.005
# 45            0.636 ± 0.012  86.071 ± 1.019  0.196 ± 0.020  0.978 ± 0.002
# 46            0.644 ± 0.014  78.161 ± 1.280  0.259 ± 0.011  0.967 ± 0.001
# 47            0.570 ± 0.023  77.478 ± 0.107  0.295 ± 0.018  0.963 ± 0.003

# %% [markdown]
# ## Análisis más detallado por columna

# %%
df = pd.read_csv("results/3dshapes/results_3dshapes.csv")
metric = "acc"
print(df)
df = df.drop(0)

task_cols = ['floor_hue', 'object_hue', 'orientation', 'scale', 'shape', 'wall_hue']
new_task_cols = [f"{metric}.{i}" if i > 0 else metric for i, x in enumerate(task_cols)]
df[new_task_cols] = df[new_task_cols].apply(pd.to_numeric, errors='coerce')
# Ordenar y limpiar nombres de modelo
df['model'] = df['model'].apply(lambda x: names[x])
df['model'] = pd.Categorical(df['model'], categories=custom_order, ordered=True)
df = df[~df["model"].isin(exclude_models)]
df = df.sort_values('model')

models = ['train','id','ood']

# Group and compute mean and std
grouped = df.groupby(['split','dataset','sub_dataset', 'model'])[new_task_cols].agg(['mean', 'std'])

# Flatten MultiIndex columns: ('floor_hue', 'mean') → 'floor_hue_mean'
grouped.columns = ['_'.join(col).strip() for col in grouped.columns.values]
grouped = grouped.reset_index()

# Format each task column as "mean ± std"
for col in new_task_cols:
    
    mean_col = f'{col}_mean'
    std_col = f'{col}_std'
    grouped[col] = grouped.apply(
        lambda row: f"{row[mean_col]:.3f} ± {row[std_col]:.3f}", axis=1
    )

# Drop the now-redundant mean and std columns
grouped = grouped.drop(columns=[f'{col}_mean' for col in new_task_cols] + [f'{col}_std' for col in new_task_cols])
grouped.rename(columns={a:b for a, b in zip(new_task_cols, task_cols)}, inplace=True)
#result = df_model.groupby(['sub_dataset', 'model'])[['floor_hue', 'object_hue', 'orientation','scale','shape','wall_hue','r2']].mean().reset_index()
#  tables[model] = grouped
# Out:
#     Unnamed: 0  split   dataset    sub_dataset  \
# 0         task    NaN       NaN            NaN
# 1            0     id  3dshapes    composition
# 2            1    ood  3dshapes    composition
# 3            2  train  3dshapes    composition
# 4            0     id  3dshapes    composition
# ..         ...    ...       ...            ...
# 542          1    ood  3dshapes  interpolation
# 543          2  train  3dshapes  interpolation
# 544          0     id  3dshapes  extrapolation
# 545          1    ood  3dshapes  extrapolation
# 546          2  train  3dshapes  extrapolation
#
#                                     model                acc  \
# 0                                     NaN          floor_hue
# 1    rep_train_same_linop_vit_l_32_random   99.9869704246521
# 2    rep_train_same_linop_vit_l_32_random  95.54184079170228
# 3    rep_train_same_linop_vit_l_32_random   99.9978244304657
# 4    rep_train_same_linop_vit_l_32_random   99.9869704246521
# ..                                    ...                ...
# 542  mod_regression_trans_vit_l_32_random  71.35085463523865
# 543  mod_regression_trans_vit_l_32_random   99.8930037021637
# 544  mod_regression_trans_vit_l_32_random  98.48094582557678
# 545  mod_regression_trans_vit_l_32_random  60.11865735054016
# 546  mod_regression_trans_vit_l_32_random  98.66400361061096
#
#                  acc.1               acc.2              acc.3  \
# 0           object_hue         orientation              scale
# 1    99.75882172584534   99.47201013565063  99.67408180236816
# 2    76.20609402656555  53.563469648361206   84.3875527381897
# 3     99.9362587928772   99.73925352096558  99.91380572319032
# 4     99.8240053653717   99.43941831588744   99.5697855949402
# ..                 ...                 ...                ...
# 542   69.4705069065094   68.02347898483276  59.24028158187866
# 543  98.62180948257446   97.24738001823424  95.51202058792114
# 544   97.3145306110382   95.86328864097597  95.68018913269044
# 545  62.76101469993591   55.36860823631287  47.04850912094116
# 546  97.50508666038512    96.6701865196228  96.60537838935852
#
#                  acc.4  ...                  r2                r2.1  \
# 0                shape  ...           floor_hue          object_hue
# 1    99.99348521232604  ...   0.999508500099182  0.9991647601127625
# 2    99.92559552192688  ...  0.9912113547325134  0.9169597029685974
# 3    99.99927282333374  ...  0.9995591044425964  0.9993557333946228
# 4                100.0  ...  0.9994682669639589   0.999309778213501
# ..                 ...  ...                 ...                 ...
# 542  99.57178235054016  ...    0.94700688123703  0.9548665285110474
# 543   99.8839557170868  ...   0.999646246433258   0.998586356639862
# 544   99.9118447303772  ...  0.9947685599327089  0.9919323325157166
# 545  97.15646505355836  ...  0.6342004537582397  0.5486479997634888
# 546  99.90128874778748  ...   0.995778739452362  0.9922668933868408
#
#                    r2.2   r2.3                r2.4                r2.5  \
# 0           orientation   same               scale               shape
# 1    0.9992913603782654  -10.0   0.996596097946167  0.9980093240737916
# 2     0.956951141357422  -10.0  0.9756580591201782  0.9946098923683168
# 3    0.9994820952415466  -10.0  0.9972704648971558  0.9980632662773132
# 4    0.9993568658828736  -10.0  0.9969083666801452  0.9986361265182496
# ..                  ...    ...                 ...                 ...
# 542  0.9640530347824096  -10.0  0.9158477187156676   0.997006893157959
# 543     0.9984011054039  -10.0  0.9932698607444764   0.999102771282196
# 544  0.9953070878982544  -10.0  0.9857628345489502  0.9972609877586364
# 545  0.2294937372207641  -10.0  0.7888743877410889  0.9792988896369934
# 546  0.9969014525413512  -10.0  0.9887291789054872  0.9972594380378724
#
#                    r2.6   acc_mean   r2_mean  mse_mean
# 0              wall_hue        NaN       NaN       NaN
# 1    0.9996792674064636  99.809883  0.998708  0.008679
# 2    0.9896599650382996  84.088252  0.970842  0.252534
# 3    0.9997249841690063  99.930586  0.998909  0.006966
# 4    0.9995903968811036  99.802277  0.998878  0.008012
# ..                  ...        ...       ...       ...
# 542  0.9416310787200928  73.140946  0.953402  0.387943
# 543  0.9994643330574036  98.473238  0.998078  0.015670
# 544  0.9889732003211976  97.540579  0.992334  0.038136
# 545  0.5363750457763672  64.432273  0.619482  4.707898
# 546  0.9901819229125975  97.895537  0.993520  0.031249
#
# [547 rows x 28 columns]
# /tmp/ipykernel_666594/3812630875.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['split','dataset','sub_dataset', 'model'])[new_task_cols].agg(['mean', 'std'])

# %%
grouped[grouped['split']=="ood"]
# Out:
#     split   dataset    sub_dataset                     model        floor_hue  \
# 57    ood  3dshapes    composition        CNN-REG (BASELINE)  100.000 ± 0.000
# 58    ood  3dshapes    composition            REG (BASELINE)   97.970 ± 0.608
# 59    ood  3dshapes    composition                    MODREG  70.610 ± 13.056
# 60    ood  3dshapes    composition            CNN-MODREG+RDM        nan ± nan
# 61    ood  3dshapes    composition                MODREG+RDM   98.004 ± 0.658
# 62    ood  3dshapes    composition         MODREG(TRANS)+RDM  49.992 ± 29.759
# 63    ood  3dshapes    composition        MODREG(LATDIR)+RDM   96.523 ± 4.097
# 64    ood  3dshapes    composition         MODREG(LINOP)+RDM   98.075 ± 0.801
# 65    ood  3dshapes    composition            LSM(CLASS)+REG     26.393 ± nan
# 66    ood  3dshapes    composition     CNN-LSM(SAME)+REG+RDM  81.310 ± 20.508
# 67    ood  3dshapes    composition        LSM(CLASS)+REG+RDM   93.193 ± 5.402
# 68    ood  3dshapes    composition             LSM(SAME)+REG   80.490 ± 3.977
# 69    ood  3dshapes    composition         LSM(SAME)+REG+RDM   97.405 ± 1.047
# 70    ood  3dshapes    composition         LSM(SAME,RES)+REG   84.342 ± 3.156
# 71    ood  3dshapes    composition     LSM(SAME,RES)+REG+RDM   98.549 ± 0.579
# 72    ood  3dshapes    composition   LSM(SAME,TRANS)+REG+RDM   53.559 ± 6.267
# 73    ood  3dshapes    composition    LSM(SAME,FILM)+REG+RDM   98.517 ± 0.366
# 74    ood  3dshapes    composition   LSM(SAME,LINOP)+REG+RDM   93.738 ± 2.143
# 75    ood  3dshapes    composition  LSM(SAME,LATDIR)+REG+RDM   96.951 ± 2.499
# 76    ood  3dshapes  extrapolation        CNN-REG (BASELINE)   71.132 ± 0.000
# 77    ood  3dshapes  extrapolation            REG (BASELINE)   70.127 ± 0.851
# 78    ood  3dshapes  extrapolation                    MODREG   70.017 ± 0.373
# 79    ood  3dshapes  extrapolation            CNN-MODREG+RDM   71.132 ± 0.000
# 80    ood  3dshapes  extrapolation                MODREG+RDM   69.761 ± 0.230
# 81    ood  3dshapes  extrapolation         MODREG(TRANS)+RDM   62.619 ± 1.877
# 82    ood  3dshapes  extrapolation        MODREG(LATDIR)+RDM   70.272 ± 0.555
# 83    ood  3dshapes  extrapolation         MODREG(LINOP)+RDM   69.652 ± 0.642
# 84    ood  3dshapes  extrapolation            LSM(CLASS)+REG     63.368 ± nan
# 85    ood  3dshapes  extrapolation     CNN-LSM(SAME)+REG+RDM   71.132 ± 0.000
# 86    ood  3dshapes  extrapolation        LSM(CLASS)+REG+RDM   68.981 ± 0.500
# 87    ood  3dshapes  extrapolation             LSM(SAME)+REG   66.206 ± 2.552
# 88    ood  3dshapes  extrapolation         LSM(SAME)+REG+RDM   68.783 ± 0.775
# 89    ood  3dshapes  extrapolation         LSM(SAME,RES)+REG   70.182 ± 0.093
# 90    ood  3dshapes  extrapolation     LSM(SAME,RES)+REG+RDM   69.187 ± 0.933
# 91    ood  3dshapes  extrapolation   LSM(SAME,TRANS)+REG+RDM   67.305 ± 0.679
# 92    ood  3dshapes  extrapolation    LSM(SAME,FILM)+REG+RDM   69.862 ± 0.520
# 93    ood  3dshapes  extrapolation   LSM(SAME,LINOP)+REG+RDM   68.424 ± 0.298
# 94    ood  3dshapes  extrapolation  LSM(SAME,LATDIR)+REG+RDM   70.315 ± 0.569
# 95    ood  3dshapes  interpolation        CNN-REG (BASELINE)   71.827 ± 1.205
# 96    ood  3dshapes  interpolation            REG (BASELINE)        nan ± nan
# 97    ood  3dshapes  interpolation                    MODREG   78.207 ± 2.494
# 98    ood  3dshapes  interpolation            CNN-MODREG+RDM   71.881 ± 1.294
# 99    ood  3dshapes  interpolation                MODREG+RDM        nan ± nan
# 100   ood  3dshapes  interpolation         MODREG(TRANS)+RDM   70.853 ± 0.721
# 101   ood  3dshapes  interpolation        MODREG(LATDIR)+RDM   76.018 ± 2.123
# 102   ood  3dshapes  interpolation         MODREG(LINOP)+RDM   81.668 ± 1.632
# 103   ood  3dshapes  interpolation            LSM(CLASS)+REG     75.603 ± nan
# 104   ood  3dshapes  interpolation     CNN-LSM(SAME)+REG+RDM   71.549 ± 0.711
# 105   ood  3dshapes  interpolation        LSM(CLASS)+REG+RDM        nan ± nan
# 106   ood  3dshapes  interpolation             LSM(SAME)+REG        nan ± nan
# 107   ood  3dshapes  interpolation         LSM(SAME)+REG+RDM        nan ± nan
# 108   ood  3dshapes  interpolation         LSM(SAME,RES)+REG        nan ± nan
# 109   ood  3dshapes  interpolation     LSM(SAME,RES)+REG+RDM        nan ± nan
# 110   ood  3dshapes  interpolation   LSM(SAME,TRANS)+REG+RDM   71.603 ± 1.801
# 111   ood  3dshapes  interpolation    LSM(SAME,FILM)+REG+RDM   78.537 ± 0.242
# 112   ood  3dshapes  interpolation   LSM(SAME,LINOP)+REG+RDM   84.711 ± 0.680
# 113   ood  3dshapes  interpolation  LSM(SAME,LATDIR)+REG+RDM   74.747 ± 0.963
#
#           object_hue      orientation            scale            shape  \
# 57   100.000 ± 0.000   99.994 ± 0.010  100.000 ± 0.000   99.999 ± 0.001
# 58    89.530 ± 2.425   85.478 ± 0.231   91.664 ± 1.532   99.787 ± 0.041
# 59    74.222 ± 8.971   77.933 ± 1.718   90.193 ± 0.571   99.853 ± 0.037
# 60         nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 61    86.102 ± 3.812  78.428 ± 12.176   87.393 ± 0.420   99.828 ± 0.023
# 62   37.777 ± 18.140  42.799 ± 20.118  49.755 ± 27.691  75.188 ± 36.171
# 63    82.312 ± 6.363  72.723 ± 10.345   91.975 ± 0.040   99.839 ± 0.037
# 64    91.047 ± 1.376  73.094 ± 14.052   83.555 ± 5.318   99.853 ± 0.080
# 65      47.386 ± nan     72.294 ± nan     34.711 ± nan     99.028 ± nan
# 66   77.914 ± 21.129  79.244 ± 20.926   94.293 ± 9.884   99.493 ± 0.879
# 67    70.175 ± 1.064   57.125 ± 6.268   88.942 ± 4.765   99.862 ± 0.015
# 68    68.245 ± 6.786   63.568 ± 3.010   86.739 ± 0.541   99.835 ± 0.050
# 69    85.123 ± 3.753   76.155 ± 8.544   88.797 ± 2.424   99.892 ± 0.028
# 70   75.531 ± 12.639   71.885 ± 5.936   93.089 ± 1.188   99.811 ± 0.041
# 71    86.625 ± 3.706   75.326 ± 9.354   88.141 ± 1.418   99.780 ± 0.024
# 72    44.820 ± 9.573   49.188 ± 9.136   74.826 ± 1.566   97.462 ± 3.021
# 73    91.878 ± 0.599   82.305 ± 1.639   92.038 ± 0.837   99.834 ± 0.037
# 74    78.717 ± 6.278   58.259 ± 4.210   87.950 ± 3.145   99.889 ± 0.054
# 75   85.298 ± 10.420  79.787 ± 14.493   88.092 ± 6.016   99.802 ± 0.123
# 76    70.954 ± 0.255   68.551 ± 0.181   63.233 ± 0.549   88.839 ± 2.683
# 77    67.465 ± 1.049   60.007 ± 0.936   56.306 ± 0.490   99.167 ± 0.447
# 78    67.188 ± 0.484   56.899 ± 0.771   40.065 ± 3.561   99.317 ± 0.514
# 79    71.060 ± 0.055   65.530 ± 1.993   62.334 ± 0.338   90.755 ± 2.474
# 80    65.649 ± 2.926   60.174 ± 0.272   52.942 ± 1.670   99.188 ± 0.503
# 81    64.969 ± 2.252   56.114 ± 1.188   47.729 ± 1.848   97.793 ± 1.198
# 82    66.876 ± 1.425   59.878 ± 0.436   56.658 ± 0.377   99.626 ± 0.296
# 83    66.474 ± 0.579   58.981 ± 1.646   54.696 ± 0.254   99.712 ± 0.104
# 84      63.827 ± nan     52.607 ± nan     39.848 ± nan     98.697 ± nan
# 85    70.979 ± 0.151   63.353 ± 1.516   62.276 ± 0.087   87.612 ± 1.691
# 86    66.334 ± 0.579   60.653 ± 0.814   53.317 ± 1.091   98.584 ± 0.393
# 87    64.539 ± 1.657   52.916 ± 1.168   38.838 ± 3.529   98.990 ± 0.443
# 88    65.812 ± 2.209   59.032 ± 0.723   53.033 ± 1.354   99.626 ± 0.183
# 89    68.544 ± 0.155   55.577 ± 1.211   44.461 ± 2.831   99.189 ± 0.096
# 90    66.607 ± 1.179   58.942 ± 0.429   56.155 ± 0.671   99.101 ± 0.296
# 91    65.799 ± 1.069   55.180 ± 0.830   49.225 ± 1.255   99.047 ± 0.144
# 92    66.888 ± 0.921   59.238 ± 0.568   55.134 ± 0.358   99.318 ± 0.252
# 93    61.885 ± 2.185   56.500 ± 1.593   53.500 ± 0.195   99.599 ± 0.147
# 94    67.047 ± 1.226   60.432 ± 0.467   56.808 ± 0.683   99.682 ± 0.155
# 95    72.986 ± 1.814   87.732 ± 1.971   70.562 ± 0.889   99.886 ± 0.168
# 96         nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 97    73.551 ± 2.097   66.165 ± 7.953   81.418 ± 6.270   99.662 ± 0.413
# 98    76.107 ± 3.452   80.073 ± 2.249   70.215 ± 2.278   99.732 ± 0.371
# 99         nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 100   69.239 ± 0.194   69.277 ± 1.505   60.779 ± 2.585   99.559 ± 0.115
# 101   74.263 ± 1.447   76.867 ± 6.896   67.149 ± 0.781   99.921 ± 0.071
# 102   80.134 ± 1.173   82.279 ± 1.427   86.302 ± 3.599   99.939 ± 0.046
# 103     73.282 ± nan     80.437 ± nan     71.753 ± nan     99.591 ± nan
# 104   76.619 ± 5.053   80.317 ± 5.304   70.818 ± 2.375   99.350 ± 0.907
# 105        nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 106        nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 107        nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 108        nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 109        nan ± nan        nan ± nan        nan ± nan        nan ± nan
# 110   69.698 ± 0.445  58.109 ± 10.484   61.065 ± 1.458   99.571 ± 0.125
# 111   73.555 ± 0.581   78.206 ± 2.047   81.643 ± 8.148   99.927 ± 0.028
# 112   79.379 ± 3.430   79.801 ± 0.916   86.500 ± 2.349   99.739 ± 0.169
# 113   73.462 ± 0.691   78.198 ± 1.635   65.717 ± 0.391   99.967 ± 0.011
#
#             wall_hue
# 57   100.000 ± 0.000
# 58    97.107 ± 0.707
# 59    82.790 ± 7.107
# 60         nan ± nan
# 61    97.820 ± 0.193
# 62   49.475 ± 20.706
# 63    95.766 ± 5.070
# 64    96.868 ± 0.877
# 65      39.240 ± nan
# 66   84.226 ± 18.220
# 67   87.619 ± 10.292
# 68    73.139 ± 7.020
# 69    96.422 ± 1.834
# 70    85.258 ± 7.535
# 71    98.454 ± 0.476
# 72   62.479 ± 12.119
# 73    98.556 ± 0.141
# 74    94.027 ± 0.981
# 75   88.297 ± 11.777
# 76    69.163 ± 2.163
# 77    70.331 ± 0.195
# 78    69.612 ± 0.593
# 79    69.432 ± 1.144
# 80    69.686 ± 0.085
# 81    67.632 ± 2.636
# 82    69.309 ± 2.129
# 83    70.170 ± 0.395
# 84      50.607 ± nan
# 85    69.838 ± 0.821
# 86    69.598 ± 0.455
# 87    69.192 ± 0.514
# 88    70.305 ± 0.597
# 89    70.235 ± 0.469
# 90    69.684 ± 0.394
# 91    69.252 ± 0.431
# 92    69.852 ± 0.604
# 93    68.516 ± 0.399
# 94    70.638 ± 0.128
# 95    72.025 ± 1.260
# 96         nan ± nan
# 97    77.868 ± 4.113
# 98    78.344 ± 1.800
# 99         nan ± nan
# 100   72.066 ± 1.228
# 101   73.212 ± 0.671
# 102   83.842 ± 0.730
# 103     75.251 ± nan
# 104   75.851 ± 2.797
# 105        nan ± nan
# 106        nan ± nan
# 107        nan ± nan
# 108        nan ± nan
# 109        nan ± nan
# 110   73.635 ± 1.933
# 111   74.623 ± 0.567
# 112   86.297 ± 1.371
# 113   72.779 ± 0.306

# %%
import re
import pandas as pd

def dataframe_to_tabularx(df, metric_cols=None, maximize=True):
    """
    Converts a DataFrame into LaTeX tabularx code with nice formatting:
    - Tiny stddev
    - Small font for numbers
    - Bold best value
    - Capitalized sub_dataset
    - Headers: _ replaced with space
    """

    # Infer metric columns if not provided
    if metric_cols is None:
        metric_cols = [col for col in df.columns if col not in ['sub_dataset', 'model', 'split', 'dataset']]

    # Capitalize headers and replace underscores with spaces
    header_cols = ['\\textbf{' + col.replace('_', ' ').upper() + '}' for col in ['SUB_DATASET', 'MODEL'] + metric_cols]

    # Begin LaTeX tabularx
    latex_code = []
    latex_code.append('\\begin{tabularx}{\\textwidth}{ll' + 'X' * len(metric_cols) + '}')
    latex_code.append('\\toprule')

    # Header row
    latex_code.append(' & '.join(header_cols) + ' \\\\')
    latex_code.append('\\midrule')

    last_sub_dataset = None

    # Find best per sub_dataset and metric
    best_values = {}
    for sub_dataset, group in df.groupby('sub_dataset'):
        best_values[sub_dataset] = {}
        for metric in metric_cols:
            values = group[metric].apply(lambda x: extract_main_value(x))
            if maximize:
                best_val = values.max()
            else:
                best_val = values.min()
            best_values[sub_dataset][metric] = best_val

    # For each row
    for idx, row in df.iterrows():
        current_sub_dataset = row['sub_dataset']
        if last_sub_dataset is not None and current_sub_dataset != last_sub_dataset:
            latex_code.append('\\midrule')
        last_sub_dataset = current_sub_dataset

        # Capitalize sub_dataset name
        sub_dataset_display = escape_latex(str(row['sub_dataset']).capitalize())
        model_display = escape_latex(str(row['model']))

        row_entries = [sub_dataset_display, model_display]

        for metric in metric_cols:
            value = row[metric]
            if pd.isna(value):
                formatted = ''
            else:
                main_val, std_val = extract_values(value)
                if main_val is None:
                    formatted = ''
                else:
                    # Check if this value is the best
                    is_best = (abs(main_val - best_values[current_sub_dataset][metric]) < 1e-3)
                    if std_val is not None:
                        formatted = f"\\scriptsize{{{main_val:.2f} \\tiny{{$\\pm$ {std_val:.2f}}}}}"
                    else:
                        formatted = f"\\scriptsize{{{main_val:.2f}}}"
                    if is_best:
                        formatted = f"\\textbf{{{formatted}}}"
            row_entries.append(escape_latex(formatted))

        latex_code.append(' & '.join(row_entries) + ' \\\\')

    # End LaTeX table
    latex_code.append('\\bottomrule')
    latex_code.append('\\end{tabularx}')

    return '\n'.join(latex_code)

# Helper function to extract mean and std from a string
def extract_values(value):
    if isinstance(value, str):
        match = re.match(r"([\d\.\-eE]+)\s*±\s*([\d\.\-eE]+)", value)
        if match:
            mean_val = float(match.group(1))
            std_val = float(match.group(2))
            if std_val != std_val:  # NaN check
                std_val = None
            return mean_val, std_val
        else:
            try:
                return float(value), None
            except:
                return None, None
    return None, None

# Helper function to extract only mean value
def extract_main_value(value):
    mean, _ = extract_values(value)
    return mean

# Helper function to escape LaTeX special characters
def escape_latex(s):
    if not isinstance(s, str):
        return s
    return (s.replace('\\', '\\textbackslash{}')
             .replace('&', '\\&')
             .replace('%', '\\%')
             .replace('$', '\\$')
             .replace('#', '\\#')
             .replace('_', '\\_')
             .replace('{', '\\{')
             .replace('}', '\\}')
             .replace('~', '\\textasciitilde{}')
             .replace('^', '\\textasciicircum{}'))
latex_code = dataframe_to_tabularx(
    grouped[grouped['split']=="ood"],
    metric_cols=['floor_hue', 'object_hue', 'orientation', 'scale', 'shape', 'wall_hue'],
    maximize=True
)

print(latex_code)
# Out:
# \begin{tabularx}{\textwidth}{llXXXXXX}
# \toprule
# \textbf{SUB DATASET} & \textbf{MODEL} & \textbf{FLOOR HUE} & \textbf{OBJECT HUE} & \textbf{ORIENTATION} & \textbf{SCALE} & \textbf{SHAPE} & \textbf{WALL HUE} \\
# \midrule
# Composition & CNN-REG (BASELINE) & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{100.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{100.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{99.99 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.01\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{100.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{100.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{100.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} \\
# Composition & REG (BASELINE) & \textbackslash\{\}scriptsize\{97.97 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.61\}\} & \textbackslash\{\}scriptsize\{89.53 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.42\}\} & \textbackslash\{\}scriptsize\{85.48 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.23\}\} & \textbackslash\{\}scriptsize\{91.66 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.53\}\} & \textbackslash\{\}scriptsize\{99.79 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{97.11 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.71\}\} \\
# Composition & MODREG & \textbackslash\{\}scriptsize\{70.61 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 13.06\}\} & \textbackslash\{\}scriptsize\{74.22 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 8.97\}\} & \textbackslash\{\}scriptsize\{77.93 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.72\}\} & \textbackslash\{\}scriptsize\{90.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.57\}\} & \textbackslash\{\}scriptsize\{99.85 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{82.79 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 7.11\}\} \\
# Composition & CNN-MODREG+RDM &  &  &  &  &  &  \\
# Composition & MODREG+RDM & \textbackslash\{\}scriptsize\{98.00 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.66\}\} & \textbackslash\{\}scriptsize\{86.10 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.81\}\} & \textbackslash\{\}scriptsize\{78.43 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 12.18\}\} & \textbackslash\{\}scriptsize\{87.39 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.42\}\} & \textbackslash\{\}scriptsize\{99.83 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.02\}\} & \textbackslash\{\}scriptsize\{97.82 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.19\}\} \\
# Composition & MODREG(TRANS)+RDM & \textbackslash\{\}scriptsize\{49.99 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 29.76\}\} & \textbackslash\{\}scriptsize\{37.78 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 18.14\}\} & \textbackslash\{\}scriptsize\{42.80 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 20.12\}\} & \textbackslash\{\}scriptsize\{49.76 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 27.69\}\} & \textbackslash\{\}scriptsize\{75.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 36.17\}\} & \textbackslash\{\}scriptsize\{49.48 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 20.71\}\} \\
# Composition & MODREG(LATDIR)+RDM & \textbackslash\{\}scriptsize\{96.52 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 4.10\}\} & \textbackslash\{\}scriptsize\{82.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.36\}\} & \textbackslash\{\}scriptsize\{72.72 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 10.35\}\} & \textbackslash\{\}scriptsize\{91.97 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{99.84 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{95.77 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.07\}\} \\
# Composition & MODREG(LINOP)+RDM & \textbackslash\{\}scriptsize\{98.08 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.80\}\} & \textbackslash\{\}scriptsize\{91.05 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.38\}\} & \textbackslash\{\}scriptsize\{73.09 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 14.05\}\} & \textbackslash\{\}scriptsize\{83.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.32\}\} & \textbackslash\{\}scriptsize\{99.85 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.08\}\} & \textbackslash\{\}scriptsize\{96.87 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.88\}\} \\
# Composition & LSM(CLASS)+REG &  &  &  &  &  &  \\
# Composition & CNN-LSM(SAME)+REG+RDM & \textbackslash\{\}scriptsize\{81.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 20.51\}\} & \textbackslash\{\}scriptsize\{77.91 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 21.13\}\} & \textbackslash\{\}scriptsize\{79.24 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 20.93\}\} & \textbackslash\{\}scriptsize\{94.29 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 9.88\}\} & \textbackslash\{\}scriptsize\{99.49 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.88\}\} & \textbackslash\{\}scriptsize\{84.23 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 18.22\}\} \\
# Composition & LSM(CLASS)+REG+RDM & \textbackslash\{\}scriptsize\{93.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.40\}\} & \textbackslash\{\}scriptsize\{70.17 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.06\}\} & \textbackslash\{\}scriptsize\{57.12 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.27\}\} & \textbackslash\{\}scriptsize\{88.94 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 4.76\}\} & \textbackslash\{\}scriptsize\{99.86 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.01\}\} & \textbackslash\{\}scriptsize\{87.62 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 10.29\}\} \\
# Composition & LSM(SAME)+REG & \textbackslash\{\}scriptsize\{80.49 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.98\}\} & \textbackslash\{\}scriptsize\{68.25 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.79\}\} & \textbackslash\{\}scriptsize\{63.57 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.01\}\} & \textbackslash\{\}scriptsize\{86.74 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.54\}\} & \textbackslash\{\}scriptsize\{99.83 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.05\}\} & \textbackslash\{\}scriptsize\{73.14 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 7.02\}\} \\
# Composition & LSM(SAME)+REG+RDM & \textbackslash\{\}scriptsize\{97.41 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.05\}\} & \textbackslash\{\}scriptsize\{85.12 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.75\}\} & \textbackslash\{\}scriptsize\{76.16 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 8.54\}\} & \textbackslash\{\}scriptsize\{88.80 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.42\}\} & \textbackslash\{\}scriptsize\{99.89 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.03\}\} & \textbackslash\{\}scriptsize\{96.42 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.83\}\} \\
# Composition & LSM(SAME,RES)+REG & \textbackslash\{\}scriptsize\{84.34 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.16\}\} & \textbackslash\{\}scriptsize\{75.53 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 12.64\}\} & \textbackslash\{\}scriptsize\{71.89 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.94\}\} & \textbackslash\{\}scriptsize\{93.09 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.19\}\} & \textbackslash\{\}scriptsize\{99.81 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{85.26 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 7.54\}\} \\
# Composition & LSM(SAME,RES)+REG+RDM & \textbackslash\{\}scriptsize\{98.55 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.58\}\} & \textbackslash\{\}scriptsize\{86.62 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.71\}\} & \textbackslash\{\}scriptsize\{75.33 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 9.35\}\} & \textbackslash\{\}scriptsize\{88.14 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.42\}\} & \textbackslash\{\}scriptsize\{99.78 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.02\}\} & \textbackslash\{\}scriptsize\{98.45 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.48\}\} \\
# Composition & LSM(SAME,TRANS)+REG+RDM & \textbackslash\{\}scriptsize\{53.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.27\}\} & \textbackslash\{\}scriptsize\{44.82 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 9.57\}\} & \textbackslash\{\}scriptsize\{49.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 9.14\}\} & \textbackslash\{\}scriptsize\{74.83 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.57\}\} & \textbackslash\{\}scriptsize\{97.46 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.02\}\} & \textbackslash\{\}scriptsize\{62.48 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 12.12\}\} \\
# Composition & LSM(SAME,FILM)+REG+RDM & \textbackslash\{\}scriptsize\{98.52 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.37\}\} & \textbackslash\{\}scriptsize\{91.88 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.60\}\} & \textbackslash\{\}scriptsize\{82.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.64\}\} & \textbackslash\{\}scriptsize\{92.04 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.84\}\} & \textbackslash\{\}scriptsize\{99.83 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.04\}\} & \textbackslash\{\}scriptsize\{98.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.14\}\} \\
# Composition & LSM(SAME,LINOP)+REG+RDM & \textbackslash\{\}scriptsize\{93.74 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.14\}\} & \textbackslash\{\}scriptsize\{78.72 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.28\}\} & \textbackslash\{\}scriptsize\{58.26 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 4.21\}\} & \textbackslash\{\}scriptsize\{87.95 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.15\}\} & \textbackslash\{\}scriptsize\{99.89 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.05\}\} & \textbackslash\{\}scriptsize\{94.03 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.98\}\} \\
# Composition & LSM(SAME,LATDIR)+REG+RDM & \textbackslash\{\}scriptsize\{96.95 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.50\}\} & \textbackslash\{\}scriptsize\{85.30 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 10.42\}\} & \textbackslash\{\}scriptsize\{79.79 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 14.49\}\} & \textbackslash\{\}scriptsize\{88.09 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.02\}\} & \textbackslash\{\}scriptsize\{99.80 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.12\}\} & \textbackslash\{\}scriptsize\{88.30 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 11.78\}\} \\
# \midrule
# Extrapolation & CNN-REG (BASELINE) & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{71.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}scriptsize\{70.95 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.26\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{68.55 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.18\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{63.23 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.55\}\}\} & \textbackslash\{\}scriptsize\{88.84 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.68\}\} & \textbackslash\{\}scriptsize\{69.16 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.16\}\} \\
# Extrapolation & REG (BASELINE) & \textbackslash\{\}scriptsize\{70.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.85\}\} & \textbackslash\{\}scriptsize\{67.47 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.05\}\} & \textbackslash\{\}scriptsize\{60.01 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.94\}\} & \textbackslash\{\}scriptsize\{56.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.49\}\} & \textbackslash\{\}scriptsize\{99.17 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.45\}\} & \textbackslash\{\}scriptsize\{70.33 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.20\}\} \\
# Extrapolation & MODREG & \textbackslash\{\}scriptsize\{70.02 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.37\}\} & \textbackslash\{\}scriptsize\{67.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.48\}\} & \textbackslash\{\}scriptsize\{56.90 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.77\}\} & \textbackslash\{\}scriptsize\{40.06 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.56\}\} & \textbackslash\{\}scriptsize\{99.32 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.51\}\} & \textbackslash\{\}scriptsize\{69.61 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.59\}\} \\
# Extrapolation & CNN-MODREG+RDM & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{71.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{71.06 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.06\}\}\} & \textbackslash\{\}scriptsize\{65.53 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.99\}\} & \textbackslash\{\}scriptsize\{62.33 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.34\}\} & \textbackslash\{\}scriptsize\{90.75 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.47\}\} & \textbackslash\{\}scriptsize\{69.43 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.14\}\} \\
# Extrapolation & MODREG+RDM & \textbackslash\{\}scriptsize\{69.76 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.23\}\} & \textbackslash\{\}scriptsize\{65.65 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.93\}\} & \textbackslash\{\}scriptsize\{60.17 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.27\}\} & \textbackslash\{\}scriptsize\{52.94 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.67\}\} & \textbackslash\{\}scriptsize\{99.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.50\}\} & \textbackslash\{\}scriptsize\{69.69 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.09\}\} \\
# Extrapolation & MODREG(TRANS)+RDM & \textbackslash\{\}scriptsize\{62.62 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.88\}\} & \textbackslash\{\}scriptsize\{64.97 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.25\}\} & \textbackslash\{\}scriptsize\{56.11 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.19\}\} & \textbackslash\{\}scriptsize\{47.73 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.85\}\} & \textbackslash\{\}scriptsize\{97.79 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.20\}\} & \textbackslash\{\}scriptsize\{67.63 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.64\}\} \\
# Extrapolation & MODREG(LATDIR)+RDM & \textbackslash\{\}scriptsize\{70.27 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.56\}\} & \textbackslash\{\}scriptsize\{66.88 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.43\}\} & \textbackslash\{\}scriptsize\{59.88 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.44\}\} & \textbackslash\{\}scriptsize\{56.66 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.38\}\} & \textbackslash\{\}scriptsize\{99.63 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.30\}\} & \textbackslash\{\}scriptsize\{69.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.13\}\} \\
# Extrapolation & MODREG(LINOP)+RDM & \textbackslash\{\}scriptsize\{69.65 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.64\}\} & \textbackslash\{\}scriptsize\{66.47 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.58\}\} & \textbackslash\{\}scriptsize\{58.98 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.65\}\} & \textbackslash\{\}scriptsize\{54.70 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.25\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{99.71 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.10\}\}\} & \textbackslash\{\}scriptsize\{70.17 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.40\}\} \\
# Extrapolation & LSM(CLASS)+REG &  &  &  &  &  &  \\
# Extrapolation & CNN-LSM(SAME)+REG+RDM & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{71.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.00\}\}\} & \textbackslash\{\}scriptsize\{70.98 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.15\}\} & \textbackslash\{\}scriptsize\{63.35 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.52\}\} & \textbackslash\{\}scriptsize\{62.28 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.09\}\} & \textbackslash\{\}scriptsize\{87.61 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.69\}\} & \textbackslash\{\}scriptsize\{69.84 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.82\}\} \\
# Extrapolation & LSM(CLASS)+REG+RDM & \textbackslash\{\}scriptsize\{68.98 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.50\}\} & \textbackslash\{\}scriptsize\{66.33 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.58\}\} & \textbackslash\{\}scriptsize\{60.65 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.81\}\} & \textbackslash\{\}scriptsize\{53.32 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.09\}\} & \textbackslash\{\}scriptsize\{98.58 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.39\}\} & \textbackslash\{\}scriptsize\{69.60 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.46\}\} \\
# Extrapolation & LSM(SAME)+REG & \textbackslash\{\}scriptsize\{66.21 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.55\}\} & \textbackslash\{\}scriptsize\{64.54 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.66\}\} & \textbackslash\{\}scriptsize\{52.92 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.17\}\} & \textbackslash\{\}scriptsize\{38.84 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.53\}\} & \textbackslash\{\}scriptsize\{98.99 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.44\}\} & \textbackslash\{\}scriptsize\{69.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.51\}\} \\
# Extrapolation & LSM(SAME)+REG+RDM & \textbackslash\{\}scriptsize\{68.78 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.78\}\} & \textbackslash\{\}scriptsize\{65.81 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.21\}\} & \textbackslash\{\}scriptsize\{59.03 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.72\}\} & \textbackslash\{\}scriptsize\{53.03 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.35\}\} & \textbackslash\{\}scriptsize\{99.63 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.18\}\} & \textbackslash\{\}scriptsize\{70.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.60\}\} \\
# Extrapolation & LSM(SAME,RES)+REG & \textbackslash\{\}scriptsize\{70.18 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.09\}\} & \textbackslash\{\}scriptsize\{68.54 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.15\}\} & \textbackslash\{\}scriptsize\{55.58 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.21\}\} & \textbackslash\{\}scriptsize\{44.46 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.83\}\} & \textbackslash\{\}scriptsize\{99.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.10\}\} & \textbackslash\{\}scriptsize\{70.23 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.47\}\} \\
# Extrapolation & LSM(SAME,RES)+REG+RDM & \textbackslash\{\}scriptsize\{69.19 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.93\}\} & \textbackslash\{\}scriptsize\{66.61 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.18\}\} & \textbackslash\{\}scriptsize\{58.94 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.43\}\} & \textbackslash\{\}scriptsize\{56.16 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.67\}\} & \textbackslash\{\}scriptsize\{99.10 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.30\}\} & \textbackslash\{\}scriptsize\{69.68 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.39\}\} \\
# Extrapolation & LSM(SAME,TRANS)+REG+RDM & \textbackslash\{\}scriptsize\{67.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.68\}\} & \textbackslash\{\}scriptsize\{65.80 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.07\}\} & \textbackslash\{\}scriptsize\{55.18 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.83\}\} & \textbackslash\{\}scriptsize\{49.23 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.25\}\} & \textbackslash\{\}scriptsize\{99.05 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.14\}\} & \textbackslash\{\}scriptsize\{69.25 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.43\}\} \\
# Extrapolation & LSM(SAME,FILM)+REG+RDM & \textbackslash\{\}scriptsize\{69.86 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.52\}\} & \textbackslash\{\}scriptsize\{66.89 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.92\}\} & \textbackslash\{\}scriptsize\{59.24 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.57\}\} & \textbackslash\{\}scriptsize\{55.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.36\}\} & \textbackslash\{\}scriptsize\{99.32 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.25\}\} & \textbackslash\{\}scriptsize\{69.85 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.60\}\} \\
# Extrapolation & LSM(SAME,LINOP)+REG+RDM & \textbackslash\{\}scriptsize\{68.42 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.30\}\} & \textbackslash\{\}scriptsize\{61.88 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.19\}\} & \textbackslash\{\}scriptsize\{56.50 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.59\}\} & \textbackslash\{\}scriptsize\{53.50 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.20\}\} & \textbackslash\{\}scriptsize\{99.60 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.15\}\} & \textbackslash\{\}scriptsize\{68.52 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.40\}\} \\
# Extrapolation & LSM(SAME,LATDIR)+REG+RDM & \textbackslash\{\}scriptsize\{70.31 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.57\}\} & \textbackslash\{\}scriptsize\{67.05 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.23\}\} & \textbackslash\{\}scriptsize\{60.43 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.47\}\} & \textbackslash\{\}scriptsize\{56.81 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.68\}\} & \textbackslash\{\}scriptsize\{99.68 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.15\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{70.64 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.13\}\}\} \\
# \midrule
# Interpolation & CNN-REG (BASELINE) & \textbackslash\{\}scriptsize\{71.83 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.21\}\} & \textbackslash\{\}scriptsize\{72.99 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.81\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{87.73 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.97\}\}\} & \textbackslash\{\}scriptsize\{70.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.89\}\} & \textbackslash\{\}scriptsize\{99.89 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.17\}\} & \textbackslash\{\}scriptsize\{72.03 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.26\}\} \\
# Interpolation & REG (BASELINE) &  &  &  &  &  &  \\
# Interpolation & MODREG & \textbackslash\{\}scriptsize\{78.21 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.49\}\} & \textbackslash\{\}scriptsize\{73.55 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.10\}\} & \textbackslash\{\}scriptsize\{66.17 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 7.95\}\} & \textbackslash\{\}scriptsize\{81.42 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.27\}\} & \textbackslash\{\}scriptsize\{99.66 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.41\}\} & \textbackslash\{\}scriptsize\{77.87 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 4.11\}\} \\
# Interpolation & CNN-MODREG+RDM & \textbackslash\{\}scriptsize\{71.88 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.29\}\} & \textbackslash\{\}scriptsize\{76.11 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.45\}\} & \textbackslash\{\}scriptsize\{80.07 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.25\}\} & \textbackslash\{\}scriptsize\{70.22 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.28\}\} & \textbackslash\{\}scriptsize\{99.73 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.37\}\} & \textbackslash\{\}scriptsize\{78.34 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.80\}\} \\
# Interpolation & MODREG+RDM &  &  &  &  &  &  \\
# Interpolation & MODREG(TRANS)+RDM & \textbackslash\{\}scriptsize\{70.85 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.72\}\} & \textbackslash\{\}scriptsize\{69.24 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.19\}\} & \textbackslash\{\}scriptsize\{69.28 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.50\}\} & \textbackslash\{\}scriptsize\{60.78 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.58\}\} & \textbackslash\{\}scriptsize\{99.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.12\}\} & \textbackslash\{\}scriptsize\{72.07 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.23\}\} \\
# Interpolation & MODREG(LATDIR)+RDM & \textbackslash\{\}scriptsize\{76.02 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.12\}\} & \textbackslash\{\}scriptsize\{74.26 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.45\}\} & \textbackslash\{\}scriptsize\{76.87 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 6.90\}\} & \textbackslash\{\}scriptsize\{67.15 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.78\}\} & \textbackslash\{\}scriptsize\{99.92 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.07\}\} & \textbackslash\{\}scriptsize\{73.21 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.67\}\} \\
# Interpolation & MODREG(LINOP)+RDM & \textbackslash\{\}scriptsize\{81.67 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.63\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{80.13 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.17\}\}\} & \textbackslash\{\}scriptsize\{82.28 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.43\}\} & \textbackslash\{\}scriptsize\{86.30 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.60\}\} & \textbackslash\{\}scriptsize\{99.94 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.05\}\} & \textbackslash\{\}scriptsize\{83.84 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.73\}\} \\
# Interpolation & LSM(CLASS)+REG &  &  &  &  &  &  \\
# Interpolation & CNN-LSM(SAME)+REG+RDM & \textbackslash\{\}scriptsize\{71.55 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.71\}\} & \textbackslash\{\}scriptsize\{76.62 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.05\}\} & \textbackslash\{\}scriptsize\{80.32 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 5.30\}\} & \textbackslash\{\}scriptsize\{70.82 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.38\}\} & \textbackslash\{\}scriptsize\{99.35 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.91\}\} & \textbackslash\{\}scriptsize\{75.85 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.80\}\} \\
# Interpolation & LSM(CLASS)+REG+RDM &  &  &  &  &  &  \\
# Interpolation & LSM(SAME)+REG &  &  &  &  &  &  \\
# Interpolation & LSM(SAME)+REG+RDM &  &  &  &  &  &  \\
# Interpolation & LSM(SAME,RES)+REG &  &  &  &  &  &  \\
# Interpolation & LSM(SAME,RES)+REG+RDM &  &  &  &  &  &  \\
# Interpolation & LSM(SAME,TRANS)+REG+RDM & \textbackslash\{\}scriptsize\{71.60 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.80\}\} & \textbackslash\{\}scriptsize\{69.70 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.45\}\} & \textbackslash\{\}scriptsize\{58.11 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 10.48\}\} & \textbackslash\{\}scriptsize\{61.06 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.46\}\} & \textbackslash\{\}scriptsize\{99.57 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.12\}\} & \textbackslash\{\}scriptsize\{73.64 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.93\}\} \\
# Interpolation & LSM(SAME,FILM)+REG+RDM & \textbackslash\{\}scriptsize\{78.54 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.24\}\} & \textbackslash\{\}scriptsize\{73.56 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.58\}\} & \textbackslash\{\}scriptsize\{78.21 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.05\}\} & \textbackslash\{\}scriptsize\{81.64 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 8.15\}\} & \textbackslash\{\}scriptsize\{99.93 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.03\}\} & \textbackslash\{\}scriptsize\{74.62 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.57\}\} \\
# Interpolation & LSM(SAME,LINOP)+REG+RDM & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{84.71 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.68\}\}\} & \textbackslash\{\}scriptsize\{79.38 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 3.43\}\} & \textbackslash\{\}scriptsize\{79.80 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.92\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{86.50 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 2.35\}\}\} & \textbackslash\{\}scriptsize\{99.74 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.17\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{86.30 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.37\}\}\} \\
# Interpolation & LSM(SAME,LATDIR)+REG+RDM & \textbackslash\{\}scriptsize\{74.75 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.96\}\} & \textbackslash\{\}scriptsize\{73.46 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.69\}\} & \textbackslash\{\}scriptsize\{78.20 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 1.64\}\} & \textbackslash\{\}scriptsize\{65.72 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.39\}\} & \textbackslash\{\}textbf\{\textbackslash\{\}scriptsize\{99.97 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.01\}\}\} & \textbackslash\{\}scriptsize\{72.78 \textbackslash\{\}tiny\{\$\textbackslash\{\}pm\$ 0.31\}\} \\
# \bottomrule
# \end{tabularx}

# %%
def df_to_tabularx(df, label, caption, column_width='\\textwidth'):
    import io

    # Copy and format DataFrame
    df_fmt = df.copy()
    df_fmt.iloc[:, 0] = df_fmt.iloc[:, 0].str.capitalize()  # sub_dataset
    df_fmt.iloc[:, 1] = df_fmt.iloc[:, 1].str.upper()       # group

    # Format numeric columns as percentages
    for col in df.columns[2:]:
        df_fmt[col] = (df[col]).map(lambda x: f"{x:.2f}")

    # Build tabularx column format
    num_task_columns = df_fmt.shape[1] - 2
    column_format = 'll' + 'X' * num_task_columns

    # Prepare bold column headers
    bold_headers = [f"\\textbf{{{col.replace('_', ' ').capitalize()}}}" for col in df_fmt.columns]

    # Use to_latex to get the content, skipping header
    buf = io.StringIO()
    df_fmt.to_latex(
        buf,
        index=False,
        header=False,
        escape=False,
        column_format=column_format
    )
    lines = buf.getvalue().splitlines()

    # Insert bold header manually
    header_line = ' & '.join(bold_headers) + ' \\\\'
    table_body = '\n'.join(lines[3:-2])  # skip to_latex's \toprule, etc.

    # Final LaTeX table
    latex = (
        f"\\begin{{table}}[ht]\n"
        f"\\centering\n"
        f"\\caption{{{caption}}}\n"
        f"\\label{{{label}}}\n"
        f"\\begin{{tabularx}}{{{column_width}}}{{{column_format}}}\n"
        f"{header_line}\n"
        f"{table_body}\n"
        f"\\end{{tabularx}}\n"
        f"\\end{{table}}"
    )

    return latex




label = "tab:asda"
caption = "Hola"
print(df_to_tabularx(tables['ood'], label, caption, column_width='\\textwidth'))
# Out:
# \begin{table}[ht]
# \centering
# \caption{Hola}
# \label{tab:asda}
# \begin{tabularx}{\textwidth}{llXXXXXXX}
# \textbf{Sub dataset} & \textbf{Model} & \textbf{Floor hue} & \textbf{Object hue} & \textbf{Orientation} & \textbf{Scale} & \textbf{Shape} & \textbf{Wall hue} & \textbf{R2} \\
# Composition & MOD_REGRESSION_VIT_L_32 & 0.91 & 0.86 & 0.95 & 0.98 & 1.00 & 0.94 & 0.94 \\
# Composition & MOD_REGRESSION_VIT_L_32_RANDOM & 0.99 & 0.93 & 0.97 & 0.98 & 1.00 & 0.99 & 0.98 \\
# Composition & NON_MOD_REGRESSION_VIT_L_32 & 0.91 & 0.85 & 0.90 & 0.98 & 1.00 & 0.89 & 0.92 \\
# Composition & REGRESSIONCNN & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 & 1.00 \\
# Composition & REP_TRAIN_PLUS_VIT_L_32 & 0.85 & 0.77 & 0.96 & 0.87 & 0.98 & 0.92 & 0.89 \\
# Composition & REP_TRAIN_PLUS_VIT_L_32_RANDOM & 0.99 & 0.84 & 0.95 & 0.98 & 1.00 & 0.98 & 0.96 \\
# Composition & REP_TRAIN_SAME_RES_VIT_L_32 & 0.95 & 0.84 & 0.96 & 0.99 & 1.00 & 0.95 & 0.95 \\
# Composition & REP_TRAIN_SAME_RES_VIT_L_32_RANDOM & 1.00 & 0.90 & 0.96 & 0.98 & 1.00 & 1.00 & 0.97 \\
# Composition & REP_TRAIN_SAME_VIT_L_32 & 0.92 & 0.84 & 0.93 & 0.98 & 1.00 & 0.94 & 0.93 \\
# Composition & REP_TRAIN_SAME_VIT_L_32_RANDOM & 0.99 & 0.91 & 0.97 & 0.98 & 1.00 & 0.99 & 0.97 \\
# Composition & VIT_L_32 & 0.99 & 0.93 & 0.98 & 0.98 & 1.00 & 0.99 & 0.98 \\
# Extrapolation & MOD_REGRESSION_VIT_L_32 & 0.35 & 0.41 & 0.12 & 0.79 & 0.99 & 0.52 & 0.53 \\
# Extrapolation & MOD_REGRESSION_VIT_L_32_RANDOM & 0.38 & 0.46 & 0.18 & 0.82 & 0.99 & 0.68 & 0.58 \\
# Extrapolation & NON_MOD_REGRESSION_VIT_L_32 & 0.39 & 0.17 & -0.35 & 0.79 & 0.99 & 0.50 & 0.42 \\
# Extrapolation & REGRESSIONCNN & -1.34 & -1.14 & 0.84 & 0.84 & 0.92 & -1.21 & -0.18 \\
# Extrapolation & REP_TRAIN_PLUS_VIT_L_32 & 0.38 & 0.40 & 0.33 & 0.79 & 0.99 & 0.38 & 0.54 \\
# Extrapolation & REP_TRAIN_PLUS_VIT_L_32_RANDOM & 0.34 & 0.49 & 0.32 & 0.75 & 0.99 & 0.59 & 0.58 \\
# Extrapolation & REP_TRAIN_SAME_RES_VIT_L_32 & 0.29 & 0.37 & 0.17 & 0.81 & 0.99 & 0.40 & 0.51 \\
# Extrapolation & REP_TRAIN_SAME_RES_VIT_L_32_RANDOM & 0.39 & 0.46 & 0.21 & 0.86 & 0.99 & 0.64 & 0.59 \\
# Extrapolation & REP_TRAIN_SAME_VIT_L_32 & 0.39 & 0.34 & 0.25 & 0.78 & 0.99 & 0.48 & 0.54 \\
# Extrapolation & REP_TRAIN_SAME_VIT_L_32_RANDOM & 0.37 & 0.46 & 0.41 & 0.83 & 0.99 & 0.60 & 0.61 \\
# Extrapolation & VIT_L_32 & 0.35 & 0.49 & 0.30 & 0.85 & 0.99 & 0.61 & 0.60 \\
# Interpolation & MOD_REGRESSION_VIT_B_32 & 0.94 & 0.95 & 0.95 & 0.96 & 0.99 & 0.93 & 0.95 \\
# Interpolation & MOD_REGRESSION_VIT_L_32 & 0.95 & 0.95 & 0.98 & 0.98 & 1.00 & 0.96 & 0.97 \\
# Interpolation & NON_MOD_REGRESSION_VIT_B_32 & 0.96 & 0.94 & 0.97 & 0.94 & 1.00 & 0.94 & 0.96 \\
# Interpolation & NON_MOD_REGRESSION_VIT_L_32 & 0.97 & 0.96 & 0.98 & 0.95 & 1.00 & 0.98 & 0.97 \\
# Interpolation & REGRESSIONCNN & 0.97 & 0.97 & 0.99 & 0.95 & 1.00 & 0.97 & 0.97 \\
# Interpolation & REP_TRAIN_PLUS_VIT_B_32 & 0.96 & 0.95 & 0.98 & 0.93 & 0.98 & 0.93 & 0.95 \\
# Interpolation & REP_TRAIN_PLUS_VIT_L_32 & 0.96 & 0.95 & 0.99 & 0.95 & 0.99 & 0.95 & 0.96 \\
# \end{tabularx}
# \end{table}

# %%
    def split_step(self, batch):    
        # Batch is simple
        imgs, gt_reps, latents = batch
        mid_reps = gt_reps if self.use_reps else self.encoder(imgs.float(), gt_reps)     # Image encoding
        mid_reps = torch.nn.functional.normalize(mid_reps, p=2.0, dim=1, eps=1e-12)
        logits = self.regressor(mid_reps)
        data = dict()
        data['logits'] = logits
        data['targets'] = latents
        return data

    def predict_regression(self, batch):
        imgs, reps, latents = batch
        reps = self.encode(imgs, reps)
        zero_deltas = torch.zeros_like(latents).float()
        if self.modulator is not None:
            reps = self.modulate(reps, zero_deltas)
        preds = self.regressor(reps)
        data = dict()
        data['logits'] = preds
        data['targets'] = latents
        return data
